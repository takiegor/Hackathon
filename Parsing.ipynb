# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd
import re
from requests.auth import HTTPDigestAuth
import os
import tqdm
import json
import datetime
from pandas.core.common import flatten
import traceback 
import webbrowser
from time import sleep

# %%
headers = {"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
           "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36",  
          }

# %%
def proceed_data(file:str, pat_gost='(ГОСТ[ ]*[0-9]+)|(ИСО[ ]*[0-9]+)', pat_name='([а-яА-ЯёЁ]{4,})'):
    """
    =====================================================================
    
    Manipulate given nomenclature data in order to maximize the quality and utility of search requests 
    during the parsing process
    
    Parameters
    ----------
    file : nomenclature of products need to find.
    pat_gost : pattern that is used to determing GOSTs of products
    pat_name : pattern that is used to determing titles of products
    
    =====================================================================
    """
    nomenclature = pd.read_excel(file, index_col='№').rename(columns={'Наименование':'FullName'})
    nomenclature.FullName = nomenclature.FullName.str.strip('*').str.strip().str.replace('\xa0','')
    
    # Find all occurencies of GOSTs info in given data 
    gost = []
    for i in range(1, len(nomenclature)+1):
        a = nomenclature.FullName.loc[i]
        b = re.findall(pat_gost, a)
        gost.append(b if b else '')
    nomenclature["Gost"] = gost
    
    # Transform gained GOSTs to appropriate form
    flattened = []
    for i in range(1,len(nomenclature)+1):
        a = nomenclature.Gost.loc[i]
        b = list(flatten(a))
        flattened.append(', '.join([x for x in b if x]))
    nomenclature['Gost'] = flattened
    
    # Highlight and leave the most import ones of GOSTs
    fixed_gost = []
    old_gosts = list(nomenclature.Gost)
    old_gosts = [i.split(',')[0] if len(i.split(','))==1 else i.split(',')[1] for i in old_gosts]
    nomenclature['Gost'] = old_gosts
    for i in range(1,len(old_gosts)+1):
        a = nomenclature.Gost.loc[i]
        b = ''.join(a.split())
        c = re.split('(\d.*)', b)
        d = ' '.join(c).strip()
        fixed_gost.append(d)
    nomenclature['Gost'] = fixed_gost
    
    # Find all products' titles with no special info
    names = []
    for i in range(1, len(nomenclature)+1):
        a = nomenclature.FullName.loc[i]
        b = re.findall(pat_name, a)
        b.pop(b.index('ГОСТ'))
        names.append(' '.join(b).lower().capitalize())
    nomenclature['Titles'] = names
    return nomenclature

# %%
data = proceed_data('poiskpostav_v1.xlsx')

# %%
def searchQuery(nomenclature:pd.DataFrame, mode='all'):
    """
    =====================================================================
    
    Construct convenient search queries to increase accuracy of parsers information
    
    Parameters
    ----------
    nomenclature : transformed nomenclature of products need to find.
    mode : {'all', 'gost', 'reasonable'}, default 'all'
        Optional parameter for constructing search queries.
        If 'all' uses FullName of product for search query.
        If 'gost' uses Gost of product for search query.
        If 'reasonable' uses combination of Gost and Name for search query.
    
    =====================================================================
    
    """
    if mode == 'all':
        searchers = list(nomenclature.FullName)
    elif mode == 'gost':
        gosts = list(nomenclature.Gost)
        searchers = gosts
    elif mode == 'reasonable':
        gosts = list(nomenclature.Gost)
        titles = list(nomenclature.Titles)
        container = list(zip(gosts, titles))
        searchers = [' '.join(x) for x in container]
    return searchers

# %%
searcher = searchQuery(data,mode='gost')

# %%
def UrlParseApi(searcher, headers, log=True):
    """
    =====================================================================
    
    Collect urls of products from https://apipost.ru/ to use them to parse products' information
    
    Parameters
    ----------
    searcher : put created search queries from searchQuery()
    headers : headers that is used to connect to site
    log : information of process duration
    
    =====================================================================
    """
    urls = []
    products = dict()
    for product in tqdm.tqdm(range(0, len(searcher))):
        a = searcher[product]
        b = a.replace(' ', '+')
        c = f'https://apipost.ru/obyavleniya/catalog/param_text_search={b}'
        d = rq.get(c, headers=headers).text
        e = BeautifulSoup(d, 'html.parser')
        f = e.find_all('tr', {'class':'tr_tab'})
        for tag1 in range(len(f)):
            g = f[tag1].find('a', {'class':'zot'})
            products[product] = products.get(product, []) + [g.get('href')]
    return products

# %%
def UrlParseOpt(searcher, headers, log=True):
    """
    =====================================================================
    
    Collect urls of products from https://www.opt-union.ru/ to use them to parse products' information
    
    Parameters
    ----------
    searcher : put created search queries from searchQuery()
    headers : headers that is used to connect to site
    log : information of process duration
    
    =====================================================================
    """
    products = dict()
    urls = []
    for product in tqdm.tqdm(range(len(searcher))):
        for page in range(1,2):
            a = searcher[product]
            b = a.replace(' ', '%20')
            c = f'https://www.opt-union.ru/search.php?words={b}&searchtype=3&page={page}'
            d = rq.get(c, headers=headers).text
            e = BeautifulSoup(d, 'html.parser')
            f = e.find_all('div', {'class': 'data-block bordered'})
            for tag in range(len(f)):
                g = f[tag].find('div', {'class': 'h2'})
                if g:
                    h = g.find('a').get('href')
                    urls.append(f'https://www.opt-union.ru{h}')
                    products[product] = products.get(product, []) + [f'https://www.opt-union.ru{h}']
    return products

# %%
def UrlParseOb(searcher, headers, log=True):
    """
    =====================================================================
    
    Collect urls of products from https://www.oborudunion.ru/ to use them to parse products' information
    
    Parameters
    ----------
    searcher : put created search queries from searchQuery()
    headers : headers that is used to connect to the site
    log : information of process duration
    
    =====================================================================
    """
    products = dict()
    urls = []
    for product in tqdm.tqdm(range(len(searcher))):
        for page in range(1,2):
            a = searcher[product]
            b = a.replace(' ', '%20')
            c = f'https://www.oborudunion.ru/search.php?words={b}&searchtype=3&page={page}'
            d = rq.get(c, headers=headers).text
            e = BeautifulSoup(d, 'html.parser')
            f = e.find_all('div', {'class': 'data-block bordered'})
            for tag in range(len(f)):
                g = f[tag].find('div', {'class': 'h2'})
                if g:
                    h = g.find('a').get('href')
                    urls.append(f'https://www.oborudunion.ru{h}')
                    products[product] = products.get(product, []) + [f'{h}']
    return products

# %%
productsOpt = UrlParseOpt(searcher, headers)
# Out:
# 100%|██████████| 40/40 [00:52<00:00,  1.31s/it]

# %%
productsApi = UrlParseApi(searcher, headers)
# Out:
# 100%|██████████| 40/40 [00:11<00:00,  3.60it/s]

# %%
productsOb = UrlParseOb(searcher,headers)
# Out:
# 100%|██████████| 40/40 [00:15<00:00,  2.55it/s]

# %%
gosts = list(data.Gost)

# %%
def parse_optunion(products, gosts, headers):
    """    
    =====================================================================
    
    Collect products' information from https://www.opt-union.ru/
    
    Parameters
    ----------
    products : use gained from UrlParseOPT() urls to gather the product information
    gosts : GOSTs' names to structure the return value
    headers : headers that is used to connect to the site
    
    =====================================================================
    """

    dct = dict()
    start_time = datetime.datetime.now()
    for product in range(len(products)):
        pr_start = datetime.datetime.now()
        dct1 = dict()
        if product not in products:
            continue
        for x, url in enumerate(products[product]):
            response = rq.get(url, headers=headers)
            if response.status_code != 404:
                a = response.text
                b = BeautifulSoup(a, 'html.parser')
                c = b.find('div', {'class':'description'})
                d = b.find('div', {'class': 'title'}).find('a')
                j = b.find_all('div', {'class': 'warp_item'})
                if len(j) == 4:
                    e = j[2].find('div', {'class':'itemRight'})
                    f = j[3].find('div', {'class':'itemRight'})
                elif len(j) == 3:
                    e = j[1].find('div', {'class':'itemRight'})
                    f = j[2].find('div', {'class':'itemRight'})
                else:
                    e = j[3].find('div', {'class':'itemRight'})
                    f = j[4].find('div', {'class':'itemRight'})
                g = b.find('table', {'class':'main'}).find('h1')
                ad_name = g.text
                location = e.text
                firms = d.text
                number = f.text
                desc = c.text.strip()
            dct1[x] = {'ad_name':ad_name,'url':url, 'location': location, 'firm':firms, 'phone_number':number, 'desc':desc}
            print(f'{x+1}/{len(products[product])} urls of product {product+1} parsed')
        dct[gosts[product]] = dct1
        pr_end = datetime.datetime.now()
        print(f'{product+1}/{len(products)} products parsed, it took {round((pr_end-pr_start).total_seconds()/60, 1)} minutes')
    with open('resultOPT.json', 'w', encoding='UTF-8') as file:
            json.dump(dct, file, indent=4, ensure_ascii=False)
    end_time = datetime.datetime.now()
    total_time = end_time-start_time
    print(total_time)
    return dct

# %%
parse_optunion(productsOpt, gosts, headers)

# %%
def parse_apipost(products, gosts, headers):
    """    
    =====================================================================
    
    Collect products' information from https://apipost.ru/
    
    Parameters
    ----------
    products : use gained from UrlParseApi() urls to gather the product information
    gosts : GOSTs' names to structure the return value
    headers : headers that is used to connect to the site
    
    =====================================================================
    """
    pattern = '[0-9]{10,}'
    pattern1 = '[0-9]{2}\.[0-9]{2}\.[0-9]{4}'
    dct = dict()
    for product in tqdm.tqdm(range(len(products))):
        dct1 = dict()
        if product not in products:
            continue
        for x, url in enumerate(products[product]):
            a = rq.get(url, headers=headers).text
            b = BeautifulSoup(a, 'html.parser')
            c = b.find('span', {'class':'price'})
            d = b.find('span', {'style': 'color: #144986; font-size: 20px;'})
            e = b.find('b')
            f = b.find('img', {'class':'icnom'})
            g = b.find('table', {'border':"0", 'cellpadding':"3", 'cellspacing':"0", 'width':"100%"}).find('td').text
            h = re.findall(pattern, g)
            i = b.find('span', {'style': 'color: #dd0000; font-size: 18px;'})
            j = b.find('div', {'class':'opis-ads'})
            k = b.find_all('tr', {'valign':'middle'})
            l = k[4].find('td').text
            m = b.find('h1', {'class':'items'})
            ad_name = m.text
            location = i.text.strip()
            prices = c.text if c else None
            firms = d.text
            number = h[0]
            desc = j.text.replace('<br>', ' ').strip()
            reg_date = re.findall(pattern1, l)[0] if re.findall(pattern1, l) else None
            dct1[x] = {'ad_name':ad_name,'url':url, 'location': location, 'firm':firms, 'phone_number':number, 'desc':desc}
        dct[gosts[product]] = dct1
        with open('resultAPI.json', 'w', encoding='UTF-8') as file:
            json.dump(dct, file, indent=4, ensure_ascii=False)
    return dct

# %%
parse_apipost(productsApi, gosts, headers)
# Out:
# 100%|██████████| 34/34 [00:10<00:00,  3.30it/s]
# {'ГОСТ 22704': {0: {'ad_name': 'Манжеты шевронные ГОСТ 22704-77 в Самаре',
#    'url': 'https://apipost.ru/obyavleniya/items/manzhety_shevronnye_gost_22704_77_v_samare_153619',
#    'location': 'Самара, м. Алабинская',
#    'price': '100 руб.',
#    'firm': 'Антон Владимирович',
#    'reg_date': '09.02.2022',
#    'phone_number': '79967354339',
#    'desc': 'Шевронные уплотнительные манжеты: отечественные изготовленные в соответствии с ГОСТ 22704-77 и импортные, разработанные и произведенные по европейским стандартам DIN и ISO, предназначены для уплотнения цилиндров и поршней (штоков, плунжеров) гидравлических устройств работающих с высокими эксплуатационными нагрузками. Конструктивно, шевронное уплотнение состоит из опрного кольца КО, нажимного кольца КН и пакета манжет – от двух до тридцати штук (чаще всего – три). Составная конструкция позволяет уплотнению работать в тяжелых условиях, поддерживать герметичность при повреждениях уплотняемой поверхности, работать в средах загрязненных абразивными примесями. Рабочие параметры уплотнения, в большой степени зависят от применяемого для его изготовления материала. В оборудовании, работающем под высокой нагрузкой, используются износостойкие резинотканевые или полиуретановые манжеты (последние служат в два-три раза дольше). В плунжерных насосах, при высоких скоростях движения плунжера, применяются фторопластовые манжеты, имеющие минимальный коэффициент сопротивления трению и максимальную термостойкость. Силиконовые уплотнения работают в пищевой и фармацевтической промышленности, а манжеты из монолитной резины (NBR, FPM, FKM) – в общепромышленном оборудовании и при повышенных температурах. Опорные и нажимные кольца, как правило, производятся из специального материала (полиацеталь POM или полиамид PA6), но могут быть изготовлены из того же материала, что и манжеты, или интегрированы в посадочное место уплотнения. Заказ можно оформить на шевронные пакеты в сборе (КО+КН+комплект манжет), или отдельно на уплотнительные манжеты (как правило, они изнашиваются быстрее).'},
#   1: {'ad_name': 'Срочное изготовление уплотнений, манжет, сальники, кольца',
#    'url': 'https://apipost.ru/obyavleniya/items/srochnoe_izgotovlenie_uplotneniy_manzhet_salniki_kolca_153598',
#    'location': 'Самара, м. Алабинская',
#    'price': '100 руб.',
#    'firm': 'Антон Владимирович',
#    'reg_date': '09.02.2022',
#    'phone_number': '79967354339',
#    'desc': 'Мы предлагаем к поставке большой выбор гидравлических и пневматических уплотнений, манжет, сальников, колец и других РТИ в соответствии с ГОСТ 6678-53, ГОСТ 14896-84, ГОСТ 6969-54, ГОСТ 22704-77, ГОСТ 15180-86, ГОСТ 9833-73, ГОСТ 18829-73 из современных, высококачественных материалов, т. к. полиуретан (PU), резина (NBR), фторкаучук FKM или FPM, фторопласт, тефлон PTEE, полеацеталь POL и др., а так же изготовления уплотнений по образцу или чертежу Заказчика. Производим манжеты и сальники от 4 мм до 2000 мм'}},
#  'ГОСТ 8752': {0: {'ad_name': 'Манжеты армированные по ГОСТ 8752-79 сальник в Самаре',
#    'url': 'https://apipost.ru/obyavleniya/items/manzhety_armirovannye_po_gost_8752_79_salnik_v_samare_153606',
#    'location': 'Самара, м. Алабинская',
#    'price': '100 руб.',
#    'firm': 'Антон Владимирович',
#    'reg_date': '09.02.2022',
#    'phone_number': '79967354339',
#    'desc': 'Полиуретановые армированные манжеты (сальники) – альтернатива изделиям из резины в условиях эксплуатации с тяжелыми условиями, где возможен преждевременный износ и выход из строя (стойкость полиуретана к истиранию в 3-5 раз выше этого же показателя у резины), или изготавливаются на заказ для замены нестандартных уплотнений. Наше оборудование позволяет производить методом точения манжеты диаметром до 2000 мм. Точеные полиуретановые манжеты армируются кольцами из полиацетали или полиамида (РОМ, РА6). В некоторых случаях, твердости полиуретана достаточно, чтобы использовать манжеты без формообразующего кольца, т. е. неармированные.'}},
#  'ГОСТ 7338': {0: {'ad_name': 'Резинотехнические пластины ГОСТ 7338-90',
#    'url': 'https://apipost.ru/obyavleniya/items/rezinotehnicheskie_plastiny_gost_7338_90_66042',
#    'location': 'ЕКАТЕРИНБУРГ',
#    'price': '80 руб.',
#    'firm': 'ООО Универсал сбыт',
#    'reg_date': '30.01.2019',
#    'phone_number': '73432682426',
#    'desc': 'ООО "Универсал сбыт" предлагает: Технические пластины предназначены для изготовления резинотехнических изделий, служащих для уплотнения неподвижных соединений, предотвращения трения между металлическими поверхностями, для восприятия одиночных ударных нагрузок, а также в качестве прокладок, настилов и других изделий. В зависимости от назначения, конструкции и способа изготовления выпускаются следующие марки: ТМКЩ- Рабочая среда пластины ТМКЩ: воздух помещений, емкостей, сосудов; азот; инертные газы при давлении от 0,05 до 0,4МПа или вода пресная, морская, промышленная, сточная без органических растворителей и смазочных веществ; раствор солей с концентрацией до предела насыщения; кислоты, щелочи концентрацией до 20% при давлении от 0,05 до 10,0 МПа. ТКМЩ пластина работоспособна при температуре от -45°C до +80°CМБС - маслобензостойкая пластина МБС- Рабочая среда пластины МБС: воздух помещений, емкостей, сосудов; азот, инертные газы при давлении от 0,05 до 0,4 МПа или масла и топлива на нефтяной основе, бензин при давлении от 0,05 до 10,0 МПа. МБС пластина работоспособна при температуре от -40°C до +80°CАМС – атмосферомаслостойкая (ограниченно озоностойкая) техпластина –- Рабочая среда данного вида техпластины: воздух атмосферный, помещений, емкостей, сосудов; азот; инертные газы при давлении от 0,05 до 0,4МПа или масла на нефтяной основе при давлении от 0,05 до 10,0 МПа. Работоспособна при температуре от -40°C до +80°C'},
#   1: {'ad_name': 'Техпластина 2-Н-1-ТМКЩ',
#    'url': 'https://apipost.ru/obyavleniya/items/tehplastina_2_n_1_tmkshch_146353',
#    'location': 'ВОЛГОГРАД, Советский район',
#    'price': '1 000 руб.',
#    'firm': 'Илья',
#    'reg_date': '06.10.2021',
#    'phone_number': '79954136847',
#    'desc': 'Техпластина 2-Н-1-ТМКЩ 1 мм, Техпластина 2-Н-1- ТМКЩ 2 мм, Техпластина 2-Н-1-ТМКЩ 3 мм, Техпластина 2-Н-1- ТМКЩ 4 мм, Техпластина 2-Н-1- ТМКЩ 5 мм, Техпластина 2-Н-1- ТМКЩ 6 мм, Техпластина 2-Н-1- ТМКЩ 8 мм, Техпластина 2-Н-1- ТМКЩ 10 мм, Техпластина 2-Н-1- ТМКЩ 12 мм, Техпластина 2-Н-1- ТМКЩ 14 мм, Техпластина 2-Н-1- ТМКЩ 16 мм, Техпластина 2-Н-1- ТМКЩ 18 мм, Техпластина 2-Н-1- ТМКЩ 20 мм, ГОСТ 7338-90, а так же ремни, кольца уплотнительные, манжеты, полиуретан и многое другое. Российского производства, действует гибкая система скидок, отправка любыми транспортными компаниями по всей России'},
#   2: {'ad_name': 'Техпластина 2-Н-1-МБС',
#    'url': 'https://apipost.ru/obyavleniya/items/tehplastina_2_n_1_mbs_146352',
#    'location': 'ВОЛГОГРАД, Советский район',
#    'price': '100 руб.',
#    'firm': 'Илья',
#    'reg_date': '06.10.2021',
#    'phone_number': '79954136847',
#    'desc': 'Техпластина 2-Н-1-МБС 1 мм, Техпластина 2-Н-1-МБС 2 мм, Техпластина 2-Н-1-МБС 3 мм, Техпластина 2-Н-1-МБС 4 мм, Техпластина 2-Н-1-МБС 5 мм, Техпластина 2-Н-1-МБС 6 мм, Техпластина 2-Н-1-МБС 8 мм, Техпластина 2-Н-1-МБС 10 мм, Техпластина 2-Н-1-МБС 12 мм, Техпластина 2-Н-1-МБС 14 мм, Техпластина 2-Н-1-МБС 16 мм, Техпластина 2-Н-1-МБС 18 мм, Техпластина 2-Н-1-МБС 20 мм, ГОСТ 7338-90, а так же ремни, кольца уплотнительные, манжеты, полиуретан и многое другое. Российского производства, действует гибкая система скидок, отправка любыми транспортными компаниями по всей России'}},
#  'ГОСТ 5398': {0: {'ad_name': 'Пожарные рукава - в Санкт-Петербурге',
#    'url': 'https://apipost.ru/obyavleniya/items/pozharnye_rukava_v_sankt_peterburge_115894',
#    'location': 'САНКТ-ПЕТЕРБУРГ, м. Балтийская',
#    'price': '750 руб.',
#    'firm': 'Прогрессив Северо-Запад',
#    'reg_date': '30.04.2018',
#    'phone_number': '78126001949',
#    'desc': 'Пожарные рукава- Всегда по наличию на складе в Санкт-Петербурге- Огромный выбор!  Гарантия качества!  Форма оплаты: наличный и безналичный расчет!  Отгружаем во все регионы РФ! - Осуществляем доставку по СПБ и Ленинградской области- Наша организация также осуществляет поверку СИЗ с выдачей протокола испытаний на Вашу организацию! ! ! Пожарный рукав – это одно из основных первичных противопожарных средств. Он обязателен на каждом объекте и является неотъемлемым атрибутом пожарников МЧС. Устройство предназначено для подачи рабочей среды к местам возгорания. Оно устанавливается и на транспорте: автомобильном и железнодорожном. ПР обязательна в воинских частях, на водных судах – морских и речных. Технические характеристики, размеры, условия хранения, особенности эксплуатации и техобслуживания пожарных рукавов регламентируется ГОСТ Р 51049.2008. Требования государственного стандарта направлены на поддержании работоспособности оборудования, и эффективной работы в момент чрезвычайной ситуации. Пожарные рукава виды, размеры и технические характеристикиПоскольку пожарные гибкие рукава имеются различных видов, их конструкция несколько отличается друг от друга. ПР классифицируют на три группы: Всасывающие. Этот тип противопожарного инвентаря работает с помощью насоса, поэтому он должен быть максимально прочным, надежным и гибким. Данные модификации производят из резины посредством технологии вулканизации. Прочность обеспечивается за счет внешнего кожуха из ткани. Всасывающие приспособления имеют наибольший вес, относительно аналогов других видов. Диаметр таких изделий достигает 20 см, а весить они могут до 6 кг. Головками не комплектуются. Напорно-всасывающие. Этот вид имеет такие же габариты, как и всасывающие: диаметр пожарного рукава – до 20 см, вес – до 6 кг. Эта модификация предназначена для откачки воды из гидрантов и водных источников. Для забора рабочей жидкости внутри создается вакуум, поэтому шланг должен иметь металлический каркас, сверху он закрывается кожухом из прочной грубой ткани. Этот тип регламентирует отдельный ГОСТ 5398.76. Поставляется без головок. Напорные. Напорные модели в диаметре могут достигать 30 см, а по массе – до 7 кг. Этот вид пожарных рукавов подает жидкости и огнетушащие вещества к очагу пожара под избыточным давлением, поэтому основной конструкции является прочный тканевый кожух, внутренняя поверхность которого покрыта гидроизоляционными материалами: резиной, латексом или полимерами. Снаружи устанавливается металлическая арматура. ПР поставляются в полной комплектации. Важно!  При выборе первичного средства пожаротушения в первую очередь следует руководствоваться назначением, но не нужно забывать о технических характеристиках конкретной модели. Они должны соответствовать предстоящим условиям эксплуатации. - Мы работаем для ВАС!'},
#   1: {'ad_name': 'Рукав напорно-всасывающий 25мм,',
#    'url': 'https://apipost.ru/obyavleniya/items/rukav_naporno_vsasyvayushchiy_25mm_146340',
#    'location': 'ВОЛГОГРАД, Советский район',
#    'price': '1 000 руб.',
#    'firm': 'Илья',
#    'reg_date': '06.10.2021',
#    'phone_number': '79954136847',
#    'desc': 'Рукав напорно-всасывающий 25мм, Рукав напорно-всасывающий 32 мм, Рукав напорно-всасывающий 38 мм, Рукав напорно-всасывающий 50 мм, Рукав напорно-всасывающий 65 мм, Рукав напорно-всасывающий 75 мм, Рукав напорно-всасывающий 100 мм, Рукав напорно-всасывающий 125 мм, Рукав напорно-всасывающий 150 мм, Рукав напорно-всасывающий 200 мм, Рукав напорно-всасывающий 250 мм, Рукав напорно-всасывающий 300 мм, ГОСТ 5398-76 Класс Б, Класс В, Класс КЩ Класс П, Рукав напорно-всасывающий Российского производства, а так же ремни, кольца уплотнительные, манжеты, полиуретан и многое другое. действует гибкая система скидок, отправка любыми транспортными компаниями по всей России.'}},
#  'ГОСТ 18698': {0: {'ad_name': 'Рукав напорный с текстильным каркасом ГОСТ 18698-79',
#    'url': 'https://apipost.ru/obyavleniya/items/rukav_napornyy_s_tekstilnym_karkasom_gost_18698_79_146339',
#    'location': 'ВОЛГОГРАД, Советский район',
#    'price': '100 руб.',
#    'firm': 'Илья',
#    'reg_date': '06.10.2021',
#    'phone_number': '79954136847',
#    'desc': 'Рукав напорный с текстильным каркасом ГОСТ 18698-79 рукав напорный 8мм, рукав напорный 10 мм, рукав напорный 12 мм, рукав напорный 14 мм, рукав напорный 16 мм, рукав напорный 18 мм, рукав напорный 20 мм, рукав напорный 22 мм, рукав напорный 25 мм, рукав напорный 27 мм, рукав напорный 30мм, рукав напорный 32 мм, рукав напорный 35 мм, рукав напорный 38 мм, рукав напорный 40 мм, рукав напорный 42 мм, рукав напорный 50 мм, рукав напорный 54 мм, рукав напорный 60 мм, рукав напорный 70 мм, рукав напорный Российского производства, действует гибкая система скидок, отправка любыми транспортными компаниями по всей России.'}},
#  'ГОСТ 7796': {0: {'ad_name': 'Латунный и бронзовый крепеж Л63, БрКмц3-1, крепеж',
#    'url': 'https://apipost.ru/obyavleniya/items/latunnyy_i_bronzovyy_krepezh_l63_brkmc3_1_krepezh_iz_59367',
#    'location': 'Азов',
#    'price': '100 руб.',
#    'firm': 'Елена',
#    'reg_date': '08.11.2018',
#    'phone_number': '78634431483',
#    'desc': 'Производим крепежные детали по ГОСТ 5915-70, ГОСТ 5916-70, ГОСТ 7798-70, ГОСТ 7796-70, ГОСТ 11371-70 из латуни, бронзы, алюминия и других цветных сплавов. Крепеж из цветных сплавов обладает рядом преимуществ: хорошей пластичностью, стойкостью к окислению и низкотемпературному воздействию, не намагничивается. Готовы изготовить крепежные детали по индивидуальным чертежам или эскизам. Гарантированное качество, доставка по всей России.'}},
#  'ИСО 4014': {0: {'ad_name': 'Продам 2-комнатную квартиру 32 м², 1/1 эт',
#    'url': 'https://apipost.ru/obyavleniya/items/prodam_2_komnatnuyu_kvartiru_32_m_1_1_et_147662',
#    'location': 'Северская',
#    'price': '1 400 000 руб.',
#    'firm': 'Ксения',
#    'reg_date': '07.10.2021',
#    'phone_number': '79627622234',
#    'desc': 'Продается 2-х комнатная квартира в центре пгт. Черноморский, Северский район, Краснодарский край. Квартира расположена в уютном и тихом месте. Перекрыта крыша, стены дома отделаны сайдингом, пластиковые окна. Асфальтированный подъезд, все центральные коммуникации - электричество, вода, канализация, газ, отопление. На участке имеется сарай и молодой плодоносящий фруктовый сад. В пешей доступности магазины различного формата, рынок, остановка общественного транспорта. Готов к продаже. Все подробности расскажу по телефону. № 40144786'},
#   1: {'ad_name': 'Продам 2-комнатную квартиру 32 м², 1/1 эт',
#    'url': 'https://apipost.ru/obyavleniya/items/prodam_2_komnatnuyu_kvartiru_32_m_1_1_et_146410',
#    'location': 'Черноморский',
#    'price': '1 400 000 руб.',
#    'firm': 'Ксения',
#    'reg_date': '07.10.2021',
#    'phone_number': '79627622234',
#    'desc': 'Продается 2-х комнатная квартира в центре пгт. Черноморский, Северский район, Краснодарский край. Квартира расположена в уютном и тихом месте. Перекрыта крыша, стены дома отделаны сайдингом, пластиковые окна. Асфальтированный подъезд, все центральные коммуникации - электричество, вода, канализация, газ, отопление. На участке имеется сарай и молодой плодоносящий фруктовый сад. В пешей доступности магазины различного формата, рынок, остановка общественного транспорта. Готов к продаже. Все подробности расскажу по телефону. id 40144786'}},
#  'ГОСТ 5915': {0: {'ad_name': 'Латунный и бронзовый крепеж Л63, БрКмц3-1, крепеж',
#    'url': 'https://apipost.ru/obyavleniya/items/latunnyy_i_bronzovyy_krepezh_l63_brkmc3_1_krepezh_iz_59367',
#    'location': 'Азов',
#    'price': '100 руб.',
#    'firm': 'Елена',
#    'reg_date': '08.11.2018',
#    'phone_number': '78634431483',
#    'desc': 'Производим крепежные детали по ГОСТ 5915-70, ГОСТ 5916-70, ГОСТ 7798-70, ГОСТ 7796-70, ГОСТ 11371-70 из латуни, бронзы, алюминия и других цветных сплавов. Крепеж из цветных сплавов обладает рядом преимуществ: хорошей пластичностью, стойкостью к окислению и низкотемпературному воздействию, не намагничивается. Готовы изготовить крепежные детали по индивидуальным чертежам или эскизам. Гарантированное качество, доставка по всей России.'},
#   1: {'ad_name': 'Производство и поставка качественного крепежа',
#    'url': 'https://apipost.ru/obyavleniya/items/proizvodstvo_i_postavka_kachestvennogo_krepezha_77453',
#    'location': 'МОСКВА',
#    'price': '100 руб.',
#    'firm': 'Ирина',
#    'reg_date': '27.05.2019',
#    'phone_number': '78634377380',
#    'desc': 'Изготавливаем различные металлоизделия способом круглого точения со снятием стружки, сваркой, штамповкой, горячей высадкой, литьем, плазменной резкой. Гальваника, термообработка до заданного класса прочности. К продукции прилагаются сертификаты соответствия. Работаем по всей России. 1) Гайка ГОСТ 5915-70, низкая ГОСТ 5916-70, корончатая ГОСТ 5918-73, высокая ГОСТ 15523-70, шлицевая ГОСТ 11871-88, барашка ГОСТ 3032-76, с буртиком ГОСТ 8918-69, с контрящим винтом ГОСТ 12460-80, колпачковая ГОСТ 11860-85, накидная ГОСТ 13957-74, контргайка ГОСТ 8968-75; 2) Болт ГОСТ 7817-80, ГОСТ 7798-70, ГОСТ 24379.1-80, бронеболты, болт откидной ГОСТ 3033-79; 3) Шайба ГОСТ 11371-78, гровер ГОСТ 6402-70, косая ГОСТ 10906-78, кольца по ГОСТ; 4) Шпилька по всем ГОСТ; 5) Шплинт стальной и нержавеющий ГОСТ 397-79; 6) Заклепка ГОСТ 10299-80-ГОСТ 10303-80, повышенной точности ГОСТ 14797-14901-85; 7) Стальные фитинги (муфта ГОСТ 8966-75, сгон ГОСТ 8969-75, резьба, бочата, штуцер, контргайка); 8) Штифт ГОСТ 3128-3129, ГОСТ 9464-9465, ГОСТ 8741-8747, ГОСТ 12850.1-. 2, ГОСТ 10773-10774, ГОСТ 12207, ГОСТ 14229, ГОСТ 19119, ГОСТ 26862-86; 9) Винт по всем ГОСТ; 10) Соединения по наружному и внутреннему конусу: гайка накидная ГОСТ 135974-74, гайка ГОСТ 13958-74, ниппель ГОСТ 13956-74, проходники, пробки. 12) Втулки, опоры, оси, стойки, валики, заглушки, пломбы, лепестки, колонки, перемычки, наконечники, шпонки по ГОСТ и ОСТ.'},
#   2: {'ad_name': 'Гайка стальная Россия',
#    'url': 'https://apipost.ru/obyavleniya/items/gayka_stalnaya_rossiya_145029',
#    'location': 'Новосибирск',
#    'price': '72 руб.',
#    'firm': 'Ферус Новосибирск',
#    'reg_date': '10.09.2021',
#    'phone_number': '73833884659',
#    'desc': 'Диаметр (мм): 6, 10, 12, 14, 16, 20, 22, 24, 27, 30, 36, 42Марка: Ст30, 35Х, 40Х, 09Г2С, 20Х13ГОСТ/ОСТ/ТУ: ГОСТ 5915-70, ГОСТ 32484.3-2013Материал: стальСостояние изделия: новое'}},
#  'ГОСТ 7817': {0: {'ad_name': 'Производство и поставка качественного крепежа',
#    'url': 'https://apipost.ru/obyavleniya/items/proizvodstvo_i_postavka_kachestvennogo_krepezha_77453',
#    'location': 'МОСКВА',
#    'price': '100 руб.',
#    'firm': 'Ирина',
#    'reg_date': '27.05.2019',
#    'phone_number': '78634377380',
#    'desc': 'Изготавливаем различные металлоизделия способом круглого точения со снятием стружки, сваркой, штамповкой, горячей высадкой, литьем, плазменной резкой. Гальваника, термообработка до заданного класса прочности. К продукции прилагаются сертификаты соответствия. Работаем по всей России. 1) Гайка ГОСТ 5915-70, низкая ГОСТ 5916-70, корончатая ГОСТ 5918-73, высокая ГОСТ 15523-70, шлицевая ГОСТ 11871-88, барашка ГОСТ 3032-76, с буртиком ГОСТ 8918-69, с контрящим винтом ГОСТ 12460-80, колпачковая ГОСТ 11860-85, накидная ГОСТ 13957-74, контргайка ГОСТ 8968-75; 2) Болт ГОСТ 7817-80, ГОСТ 7798-70, ГОСТ 24379.1-80, бронеболты, болт откидной ГОСТ 3033-79; 3) Шайба ГОСТ 11371-78, гровер ГОСТ 6402-70, косая ГОСТ 10906-78, кольца по ГОСТ; 4) Шпилька по всем ГОСТ; 5) Шплинт стальной и нержавеющий ГОСТ 397-79; 6) Заклепка ГОСТ 10299-80-ГОСТ 10303-80, повышенной точности ГОСТ 14797-14901-85; 7) Стальные фитинги (муфта ГОСТ 8966-75, сгон ГОСТ 8969-75, резьба, бочата, штуцер, контргайка); 8) Штифт ГОСТ 3128-3129, ГОСТ 9464-9465, ГОСТ 8741-8747, ГОСТ 12850.1-. 2, ГОСТ 10773-10774, ГОСТ 12207, ГОСТ 14229, ГОСТ 19119, ГОСТ 26862-86; 9) Винт по всем ГОСТ; 10) Соединения по наружному и внутреннему конусу: гайка накидная ГОСТ 135974-74, гайка ГОСТ 13958-74, ниппель ГОСТ 13956-74, проходники, пробки. 12) Втулки, опоры, оси, стойки, валики, заглушки, пломбы, лепестки, колонки, перемычки, наконечники, шпонки по ГОСТ и ОСТ.'},
#   1: {'ad_name': 'Болт призонный гост 7817-80, болт крановый, болт для ...',
#    'url': 'https://apipost.ru/obyavleniya/items/bolt_prizonnyy_gost_7817_80_bolt_kranovyy_bolt_dlya_124985',
#    'location': 'САНКТ-ПЕТЕРБУРГ, м. Василеостровская',
#    'price': '250 руб.',
#    'firm': 'Евгений',
#    'reg_date': '05.11.2020',
#    'phone_number': '79508485519',
#    'desc': 'Специализируемся на производстве болтов ГОСТ 7817-80 с шестигранной уменьшенной головкой класс точности А для отверстий из-под развёртки. Готовы предложить изготовление полного перечня типоразмеров от М6 до М48 включительно, всех четырех исполнений (1, 1а, 2, 2а), предусмотренных ГОСТ 7817-80. По индивидуальным требованиям заказчика производим болты с мелким шагом резьбы, повышенной прочности до к. п. 10,9, а также с любым антикоррозионным покрытием на выбор заказчика. По запросу производим болты с отверстием под шплинт или без него. Шплинты по ГОСТ 397-79, а также гайки прорезные или корончатые по ГОСТ 5918-73 или ГОСТ 5919-73 так же можно заказать на нашем предприятии. Отправляем транспортной компанией на выбор заказчика.'},
#   2: {'ad_name': 'ООО Контэкс-Теплоэнергоремонт изготовит технологическое...',
#    'url': 'https://apipost.ru/obyavleniya/items/ooo_konteks_teploenergoremont_izgotovit_tehnologicheskoe_136574',
#    'location': 'ВОЛОГДА',
#    'price': '1 руб.',
#    'firm': 'Андрей',
#    'reg_date': '16.04.2021',
#    'phone_number': '78172547470',
#    'desc': 'Мы производим: деаэраторы ДА, баки аккумуляторные БДА, колонки деаэрационные КДА, охладители выпара ОВА, фильтры ФОВ, ФСУ, ФИПа I, ФИПа I I, ФМ, водоподготовительные установки ВПУ, солерастворители С, грязевики, изготавливаемые в соответствии с ГОСТ 34347-2017 «Сосуды и аппараты стальные сварные. Общие технические условия». Имеются в наличии: - ФИПа I 1,0-0,6 - 4 шт.; - ФИПа I 1,5-0,6 - 1 шт.; - ФИПа II 1,5-0,6 -1 шт.'},
#   3: {'ad_name': 'Купить болт гост 7817-80, крановый болт',
#    'url': 'https://apipost.ru/obyavleniya/items/kupit_bolt_gost_7817_80_kranovyy_bolt_125029',
#    'location': 'МОСКВА',
#    'price': '10 руб.',
#    'firm': 'Анна',
#    'reg_date': '04.04.2019',
#    'phone_number': '78634377370',
#    'desc': 'Изготовление болтов ГОСТ 7817-80 от М6 до М48 в любом из 4-х исполнений, а также по чертежам и образцам. 100% соблюдение всех норм технологического процесса. Предоставляем сертификаты на металл и сертификат соответствия изделия.'},
#   4: {'ad_name': 'Купить крановый болт гост 7817-80, купить прецизионный болт',
#    'url': 'https://apipost.ru/obyavleniya/items/kupit_kranovyy_bolt_gost_7817_80_kupit_precizionnyy_bolt_72302',
#    'location': 'КАЛУГА',
#    'price': '10 руб.',
#    'firm': 'Анна',
#    'reg_date': '04.04.2019',
#    'phone_number': '78634377370',
#    'desc': 'Компания ООО «РусСпецКрепёж» предлагает широкий выбор призонных (прецизионных, крановых) болтов ГОСТ 7817-80 изготовленных из различных сталей, с мелким или стандартным шагом резьбы. Номинальный диаметр резьбы изготавливаемых болтов от М6 до М48, все исполнения. Продукция сертифицирована. Доставка производится в любой регион страны транспортной компанией на выбор заказчика. Мошенники копируют наши объявления и указывают другие телефоны! Будьте внимательны!'},
#   5: {'ad_name': 'Призонный болт гост 7817-80 купить, болт крановый',
#    'url': 'https://apipost.ru/obyavleniya/items/prizonnyy_bolt_gost_7817_80_kupit_bolt_kranovyy_140726',
#    'location': 'КАЛУГА',
#    'price': '25 руб.',
#    'firm': 'Анна',
#    'reg_date': '04.04.2019',
#    'phone_number': '78634377370',
#    'desc': 'Крановый болт ГОСТ 7817-80 в любом исполнении, можно заказать на нашем предприятии. Изготавливаем болты, как обычных классов прочности, так и высокопрочные. Типоразмеры от М6 до М48, а также нестандартные размеры болтов по вашим чертежам, эскизам и образцам. Болт ГОСТ 7817-80 применяется совместно с гайками, шайбами и шплинтами подходящего диаметра при строительстве мостов, креплении крановых конструкций, двигателей и редукторов. Сжатые сроки изготовления, наилучшее качество!'}},
#  'ГОСТ 5916': {0: {'ad_name': 'Латунный и бронзовый крепеж Л63, БрКмц3-1, крепеж',
#    'url': 'https://apipost.ru/obyavleniya/items/latunnyy_i_bronzovyy_krepezh_l63_brkmc3_1_krepezh_iz_59367',
#    'location': 'Азов',
#    'price': '100 руб.',
#    'firm': 'Елена',
#    'reg_date': '08.11.2018',
#    'phone_number': '78634431483',
#    'desc': 'Производим крепежные детали по ГОСТ 5915-70, ГОСТ 5916-70, ГОСТ 7798-70, ГОСТ 7796-70, ГОСТ 11371-70 из латуни, бронзы, алюминия и других цветных сплавов. Крепеж из цветных сплавов обладает рядом преимуществ: хорошей пластичностью, стойкостью к окислению и низкотемпературному воздействию, не намагничивается. Готовы изготовить крепежные детали по индивидуальным чертежам или эскизам. Гарантированное качество, доставка по всей России.'},
#   1: {'ad_name': 'Производство и поставка качественного крепежа',
#    'url': 'https://apipost.ru/obyavleniya/items/proizvodstvo_i_postavka_kachestvennogo_krepezha_77453',
#    'location': 'МОСКВА',
#    'price': '100 руб.',
#    'firm': 'Ирина',
#    'reg_date': '27.05.2019',
#    'phone_number': '78634377380',
#    'desc': 'Изготавливаем различные металлоизделия способом круглого точения со снятием стружки, сваркой, штамповкой, горячей высадкой, литьем, плазменной резкой. Гальваника, термообработка до заданного класса прочности. К продукции прилагаются сертификаты соответствия. Работаем по всей России. 1) Гайка ГОСТ 5915-70, низкая ГОСТ 5916-70, корончатая ГОСТ 5918-73, высокая ГОСТ 15523-70, шлицевая ГОСТ 11871-88, барашка ГОСТ 3032-76, с буртиком ГОСТ 8918-69, с контрящим винтом ГОСТ 12460-80, колпачковая ГОСТ 11860-85, накидная ГОСТ 13957-74, контргайка ГОСТ 8968-75; 2) Болт ГОСТ 7817-80, ГОСТ 7798-70, ГОСТ 24379.1-80, бронеболты, болт откидной ГОСТ 3033-79; 3) Шайба ГОСТ 11371-78, гровер ГОСТ 6402-70, косая ГОСТ 10906-78, кольца по ГОСТ; 4) Шпилька по всем ГОСТ; 5) Шплинт стальной и нержавеющий ГОСТ 397-79; 6) Заклепка ГОСТ 10299-80-ГОСТ 10303-80, повышенной точности ГОСТ 14797-14901-85; 7) Стальные фитинги (муфта ГОСТ 8966-75, сгон ГОСТ 8969-75, резьба, бочата, штуцер, контргайка); 8) Штифт ГОСТ 3128-3129, ГОСТ 9464-9465, ГОСТ 8741-8747, ГОСТ 12850.1-. 2, ГОСТ 10773-10774, ГОСТ 12207, ГОСТ 14229, ГОСТ 19119, ГОСТ 26862-86; 9) Винт по всем ГОСТ; 10) Соединения по наружному и внутреннему конусу: гайка накидная ГОСТ 135974-74, гайка ГОСТ 13958-74, ниппель ГОСТ 13956-74, проходники, пробки. 12) Втулки, опоры, оси, стойки, валики, заглушки, пломбы, лепестки, колонки, перемычки, наконечники, шпонки по ГОСТ и ОСТ.'},
#   2: {'ad_name': 'Переключатели реечные ПТРЛ для ТМ-25 40 ТМ-63 100 160',
#    'url': 'https://apipost.ru/obyavleniya/items/pereklyuchateli_reechnye_ptrl_dlya_tm_25_40_tm_63_100_160_119473',
#    'location': 'САНКТ-ПЕТЕРБУРГ, м. Балтийская',
#    'price': None,
#    'firm': 'Прогрессив Северо-Запад',
#    'reg_date': None,
#    'phone_number': '78126001949',
#    'desc': 'Переключатели реечные ПТРЛ для ТМ-25; 40; ТМ-63; 100; 160- Ждем ВАС всегда на нашем центральном сайте. Отгружаем во все регионы РФ. Работаем со всеми ТК. Вся номенклатура зип для ремонта трансформаторов ТМ, возможно изготовление узлов по эскизам заказчикапереключатели трехфазные реечные серии ПТРЛПереключатели ПТРЛ ТМ-25; -40 Imax=5А пять фазПереключатели ПТРЛ ТМ-63; -100; -160 Imax=16А пять фазПереключатели ПТРЛ ТМ-250 Imax=25А шесть фазПереключатели ПТРЛ ТМ-400; -630; -1000 Imax=95А шесть фазголовка переключателя в сбореВвод ВН трансформатора к ТМ 25-1000 кВАВвод НН трансформатора к ТМ 25-160 кВАВвод НН трансформатора к ТМ 250 кВАВвод НН трансформатора к ТМ 400 кВАВвод НН трансформатора к ТМ 630 кВАВвод НН трансформатора к ТМ 1000 кВАГайка М12 (материал ЛС 59-1) ГОСТ 5916-70Гайка М16 (материал ЛС 59-1) ГОСТ 5916-70Гайка М20х1,5 (материал ЛС 59-1) ГОСТ 5916-70Гайка М27х1,5 (материал ЛС 59-1) ГОСТ 5916-70Гайка М33х2,0 (материал ЛС 59-1) ГОСТ 5916-70- Мы работаем не со всеми, мы работаем с каждым!'}},
#  'ГОСТ 15521': {0: {'ad_name': 'Гайка гост 15521-70 15525-70',
#    'url': 'https://apipost.ru/obyavleniya/items/gayka_gost_15521_70_15525_70_124988',
#    'location': 'АСТРАХАНЬ, Кировский район',
#    'price': '50 руб.',
#    'firm': 'Евгений',
#    'reg_date': '05.11.2020',
#    'phone_number': '79508485519',
#    'desc': 'Производим гайку ГОСТ 15521-70 – 15525-70 (высокая класс точности В). Изготавливаем все типоразмеры от М6 до М48 включительно. Гайки производятся в двух исполнениях, с крупным или мелким шагом резьбы. Марка стали, а также наличие антикоррозионного покрытия определяется заказчиком. Все изделия собственного производства. Доставка до транспортной компании бесплатно.'}}}

# %%
def parse_ob(products, gosts, headers):
    """
    =====================================================================
    
    Collect products' information from https://www.oborudunion.ru/
    
    Parameters
    ----------
    products : use gained from UrlParseOb() urls to gather the product information
    gosts : GOSTs' names to structure the return value
    headers : headers that is used to connect to the site
    
    =====================================================================
    """
    dct = dict()
    start_time = datetime.datetime.now()
    for product in range(len(products)):
        pr_start = datetime.datetime.now()
        dct1 = dict()
        if product not in products:
            continue
        for x, url in enumerate(products[product]):
            response = rq.get(url, headers=headers)
            if response.status_code != 404:
                a = response.text
                b = BeautifulSoup(a, 'html.parser')
                c = b.find('div', {'class':'description'})
                d = b.find('div', {'class': 'title'}).find('a')

                j = b.find_all('div', {'class': 'warp_item'})
                if len(j) == 4:
                    e = j[2].find('div', {'class':'itemRight'})
                    f = j[3].find('div', {'class':'itemRight'})
                elif len(j) == 3:
                    e = j[1].find('div', {'class':'itemRight'})
                    f = j[2].find('div', {'class':'itemRight'})
                else:
                    e = j[3].find('div', {'class':'itemRight'})
                    f = j[4].find('div', {'class':'itemRight'})
#                     print(c.text.strip(), d.text, e.text, f.text, sep='\n')
                g = b.find('div', {'class':'main-content__left-long'}).find('h1')
                ad_name = g.text
                location = e.text
                firms = d.text if d is not None else ''
                number = f.text
                desc = c.text.strip()
            dct1[x] = {'ad_name':ad_name,'url':url, 'location': location, 'firm':firms, 'phone_number':number, 'desc':desc}
            print(f'{x+1}/{len(products[product])} urls of product {product+1} parsed')
        dct[gosts[product]] = dct1
        pr_end = datetime.datetime.now()
        print(f'{product+1}/{len(products)} products parsed, it took {round((pr_end-pr_start).total_seconds()/60, 1)} minutes')
    with open('resultOB.json', 'w', encoding='UTF-8') as file:
            json.dump(dct, file, indent=4, ensure_ascii=False)
    end_time = datetime.datetime.now()
    total_time = end_time-start_time
    print(total_time)
    return dct

# %%
parse_ob(productsOb, gosts, headers)

# %%
def concatJSON(json1, json2, json3):
    with open(json1, 'r', encoding='UTF-8') as f:
        a = json.load(f)
        a = pd.DataFrame(a).reset_index(drop=True)
    with open(json2, 'r', encoding='UTF-8') as f:
        b = json.load(f)
        b = pd.DataFrame(b).reset_index(drop=True)
    with open(json3, 'r', encoding='UTF-8') as f:
        c = json.load(f)
        c = pd.DataFrame(c).reset_index(drop=True)
    return pd.concat([a,b,c]).reset_index(drop=True)

# %%
def parse(nomenclature:pd.DataFrame, headers, mode='all', source='all', 
          pages=1, info='all', status_log=True):
    """
    =====================================================================
    
    Parse particular resources
    
    Parameters
    ----------
    nomenclature : pd.DataFrame, transformed nomenclature of products need to find
    headers : dict, headers that is used to connect to the site
    mode : {'all', 'gost', 'reasonable'}, default 'all'
        Optional parameter for constructing search queries.
        If 'all' uses FullName of product for search query.
        If 'gost' uses Gost of product for search query.
        If 'reasonable' uses combination of Gost and Name for search query.
    source : {'all', 'apipost', 'oborudunio', 'opt-union'}, default 'all'.
        Optional parameter for searching on particular sources.
        If 'all' uses all sources to parse.
        If 'apipost' uses apipost.ru site to parse.
        If 'oborudunion' uses oborudunion.ru site to parse.
        If 'opt-union' uses opt-union.ru site to parse.
    pages : number of pages to look through on sites
    info : bool, additional info on parsing process
    status_log : bool, parsing log
    
    =====================================================================
    """
    
    searcher = searchQuery(nomenclature, mode=mode)
    gosts = list(nomenclature.Gost)
    overall = dict()
    
    if source == 'all':
        
        productsApi = UrlParseApi(searcher, headers)
        productsOb = UrlParseOb(searcher, headers)
        productsOpt = UrlParseOpt(searcher, headers)
        parsedApi = parse_apipost(productsApi, gosts, headers)
        parsedOb = parse_ob(productsOb, gosts, headers)
        parsedOpt = parse_optunion(productsOpt, gosts, headers)
        overall = dict()
        
        return concatJSON('resultAPI.json', 'resultOB.json', 'resultOPT.json')
    
    elif source == 'apipost':
        
        productsApi = UrlParseApi(searcher, headers)
        parsedApi = parse_apipost(productsApi, gosts, headers)
        
        for gost in gosts:
            
            overall[gost] = pd.DataFrame(parsedApi[gost]).T.reset_index(drop=True).to_dict() if gost in parsedApi else ''
            
        return overall
    
    elif source == 'oborudunion':
        
        productsOb = UrlParseOb(searcher, headers)
        parsedOb = pd.DataFrame(parsedOb[gost]).T
    
        for gost in gosts:
            
            overall[gost] = pd.DataFrame(parsedOb[gost]).T.reset_index(drop=True).to_dict()
    
        return overall
        
    elif source == 'opt-union':
        
        productsOpt = UrlParseOpt(searcher, headers)
        parsedOpt = parse_optunion(productsOpt, gosts, headers)
        
        for gost in gosts:
            
            overall[gost] = pd.DataFrame(parsedOpt[gost]).T.reset_index(drop=True).to_dict()
    
        return overall
    
    else:
        raise NameError('Option is not supported')

# %%
dct = parse(data, headers=headers, mode='reasonable', source='all')
dct
# Out:
# 100%|██████████| 40/40 [00:06<00:00,  6.16it/s]
# 100%|██████████| 40/40 [00:14<00:00,  2.67it/s]
# 100%|██████████| 40/40 [00:12<00:00,  3.14it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.44it/s]
# 1/21 urls of product 1 parsed
# 2/21 urls of product 1 parsed
# 3/21 urls of product 1 parsed
# 4/21 urls of product 1 parsed
# 5/21 urls of product 1 parsed
# 6/21 urls of product 1 parsed
# 7/21 urls of product 1 parsed
# 8/21 urls of product 1 parsed
# 9/21 urls of product 1 parsed
# 10/21 urls of product 1 parsed
# 11/21 urls of product 1 parsed
# 12/21 urls of product 1 parsed
# 13/21 urls of product 1 parsed
# 14/21 urls of product 1 parsed
# 15/21 urls of product 1 parsed
# 16/21 urls of product 1 parsed
# 17/21 urls of product 1 parsed
# 18/21 urls of product 1 parsed
# 19/21 urls of product 1 parsed
# 20/21 urls of product 1 parsed
# 21/21 urls of product 1 parsed
# 1/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 2 parsed
# 2/21 urls of product 2 parsed
# 3/21 urls of product 2 parsed
# 4/21 urls of product 2 parsed
# 5/21 urls of product 2 parsed
# 6/21 urls of product 2 parsed
# 7/21 urls of product 2 parsed
# 8/21 urls of product 2 parsed
# 9/21 urls of product 2 parsed
# 10/21 urls of product 2 parsed
# 11/21 urls of product 2 parsed
# 12/21 urls of product 2 parsed
# 13/21 urls of product 2 parsed
# 14/21 urls of product 2 parsed
# 15/21 urls of product 2 parsed
# 16/21 urls of product 2 parsed
# 17/21 urls of product 2 parsed
# 18/21 urls of product 2 parsed
# 19/21 urls of product 2 parsed
# 20/21 urls of product 2 parsed
# 21/21 urls of product 2 parsed
# 2/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 3 parsed
# 2/21 urls of product 3 parsed
# 3/21 urls of product 3 parsed
# 4/21 urls of product 3 parsed
# 5/21 urls of product 3 parsed
# 6/21 urls of product 3 parsed
# 7/21 urls of product 3 parsed
# 8/21 urls of product 3 parsed
# 9/21 urls of product 3 parsed
# 10/21 urls of product 3 parsed
# 11/21 urls of product 3 parsed
# 12/21 urls of product 3 parsed
# 13/21 urls of product 3 parsed
# 14/21 urls of product 3 parsed
# 15/21 urls of product 3 parsed
# 16/21 urls of product 3 parsed
# 17/21 urls of product 3 parsed
# 18/21 urls of product 3 parsed
# 19/21 urls of product 3 parsed
# 20/21 urls of product 3 parsed
# 21/21 urls of product 3 parsed
# 3/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 4 parsed
# 2/21 urls of product 4 parsed
# 3/21 urls of product 4 parsed
# 4/21 urls of product 4 parsed
# 5/21 urls of product 4 parsed
# 6/21 urls of product 4 parsed
# 7/21 urls of product 4 parsed
# 8/21 urls of product 4 parsed
# 9/21 urls of product 4 parsed
# 10/21 urls of product 4 parsed
# 11/21 urls of product 4 parsed
# 12/21 urls of product 4 parsed
# 13/21 urls of product 4 parsed
# 14/21 urls of product 4 parsed
# 15/21 urls of product 4 parsed
# 16/21 urls of product 4 parsed
# 17/21 urls of product 4 parsed
# 18/21 urls of product 4 parsed
# 19/21 urls of product 4 parsed
# 20/21 urls of product 4 parsed
# 21/21 urls of product 4 parsed
# 4/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 5 parsed
# 2/21 urls of product 5 parsed
# 3/21 urls of product 5 parsed
# 4/21 urls of product 5 parsed
# 5/21 urls of product 5 parsed
# 6/21 urls of product 5 parsed
# 7/21 urls of product 5 parsed
# 8/21 urls of product 5 parsed
# 9/21 urls of product 5 parsed
# 10/21 urls of product 5 parsed
# 11/21 urls of product 5 parsed
# 12/21 urls of product 5 parsed
# 13/21 urls of product 5 parsed
# 14/21 urls of product 5 parsed
# 15/21 urls of product 5 parsed
# 16/21 urls of product 5 parsed
# 17/21 urls of product 5 parsed
# 18/21 urls of product 5 parsed
# 19/21 urls of product 5 parsed
# 20/21 urls of product 5 parsed
# 21/21 urls of product 5 parsed
# 5/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 6 parsed
# 2/21 urls of product 6 parsed
# 3/21 urls of product 6 parsed
# 4/21 urls of product 6 parsed
# 5/21 urls of product 6 parsed
# 6/21 urls of product 6 parsed
# 7/21 urls of product 6 parsed
# 8/21 urls of product 6 parsed
# 9/21 urls of product 6 parsed
# 10/21 urls of product 6 parsed
# 11/21 urls of product 6 parsed
# 12/21 urls of product 6 parsed
# 13/21 urls of product 6 parsed
# 14/21 urls of product 6 parsed
# 15/21 urls of product 6 parsed
# 16/21 urls of product 6 parsed
# 17/21 urls of product 6 parsed
# 18/21 urls of product 6 parsed
# 19/21 urls of product 6 parsed
# 20/21 urls of product 6 parsed
# 21/21 urls of product 6 parsed
# 6/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 7 parsed
# 2/21 urls of product 7 parsed
# 3/21 urls of product 7 parsed
# 4/21 urls of product 7 parsed
# 5/21 urls of product 7 parsed
# 6/21 urls of product 7 parsed
# 7/21 urls of product 7 parsed
# 8/21 urls of product 7 parsed
# 9/21 urls of product 7 parsed
# 10/21 urls of product 7 parsed
# 11/21 urls of product 7 parsed
# 12/21 urls of product 7 parsed
# 13/21 urls of product 7 parsed
# 14/21 urls of product 7 parsed
# 15/21 urls of product 7 parsed
# 16/21 urls of product 7 parsed
# 17/21 urls of product 7 parsed
# 18/21 urls of product 7 parsed
# 19/21 urls of product 7 parsed
# 20/21 urls of product 7 parsed
# 21/21 urls of product 7 parsed
# 7/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 8 parsed
# 2/21 urls of product 8 parsed
# 3/21 urls of product 8 parsed
# 4/21 urls of product 8 parsed
# 5/21 urls of product 8 parsed
# 6/21 urls of product 8 parsed
# 7/21 urls of product 8 parsed
# 8/21 urls of product 8 parsed
# 9/21 urls of product 8 parsed
# 10/21 urls of product 8 parsed
# 11/21 urls of product 8 parsed
# 12/21 urls of product 8 parsed
# 13/21 urls of product 8 parsed
# 14/21 urls of product 8 parsed
# 15/21 urls of product 8 parsed
# 16/21 urls of product 8 parsed
# 17/21 urls of product 8 parsed
# 18/21 urls of product 8 parsed
# 19/21 urls of product 8 parsed
# 20/21 urls of product 8 parsed
# 21/21 urls of product 8 parsed
# 8/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 9 parsed
# 2/21 urls of product 9 parsed
# 3/21 urls of product 9 parsed
# 4/21 urls of product 9 parsed
# 5/21 urls of product 9 parsed
# 6/21 urls of product 9 parsed
# 7/21 urls of product 9 parsed
# 8/21 urls of product 9 parsed
# 9/21 urls of product 9 parsed
# 10/21 urls of product 9 parsed
# 11/21 urls of product 9 parsed
# 12/21 urls of product 9 parsed
# 13/21 urls of product 9 parsed
# 14/21 urls of product 9 parsed
# 15/21 urls of product 9 parsed
# 16/21 urls of product 9 parsed
# 17/21 urls of product 9 parsed
# 18/21 urls of product 9 parsed
# 19/21 urls of product 9 parsed
# 20/21 urls of product 9 parsed
# 21/21 urls of product 9 parsed
# 9/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 10 parsed
# 2/21 urls of product 10 parsed
# 3/21 urls of product 10 parsed
# 4/21 urls of product 10 parsed
# 5/21 urls of product 10 parsed
# 6/21 urls of product 10 parsed
# 7/21 urls of product 10 parsed
# 8/21 urls of product 10 parsed
# 9/21 urls of product 10 parsed
# 10/21 urls of product 10 parsed
# 11/21 urls of product 10 parsed
# 12/21 urls of product 10 parsed
# 13/21 urls of product 10 parsed
# 14/21 urls of product 10 parsed
# 15/21 urls of product 10 parsed
# 16/21 urls of product 10 parsed
# 17/21 urls of product 10 parsed
# 18/21 urls of product 10 parsed
# 19/21 urls of product 10 parsed
# 20/21 urls of product 10 parsed
# 21/21 urls of product 10 parsed
# 10/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 11 parsed
# 2/21 urls of product 11 parsed
# 3/21 urls of product 11 parsed
# 4/21 urls of product 11 parsed
# 5/21 urls of product 11 parsed
# 6/21 urls of product 11 parsed
# 7/21 urls of product 11 parsed
# 8/21 urls of product 11 parsed
# 9/21 urls of product 11 parsed
# 10/21 urls of product 11 parsed
# 11/21 urls of product 11 parsed
# 12/21 urls of product 11 parsed
# 13/21 urls of product 11 parsed
# 14/21 urls of product 11 parsed
# 15/21 urls of product 11 parsed
# 16/21 urls of product 11 parsed
# 17/21 urls of product 11 parsed
# 18/21 urls of product 11 parsed
# 19/21 urls of product 11 parsed
# 20/21 urls of product 11 parsed
# 21/21 urls of product 11 parsed
# 11/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 12 parsed
# 2/21 urls of product 12 parsed
# 3/21 urls of product 12 parsed
# 4/21 urls of product 12 parsed
# 5/21 urls of product 12 parsed
# 6/21 urls of product 12 parsed
# 7/21 urls of product 12 parsed
# 8/21 urls of product 12 parsed
# 9/21 urls of product 12 parsed
# 10/21 urls of product 12 parsed
# 11/21 urls of product 12 parsed
# 12/21 urls of product 12 parsed
# 13/21 urls of product 12 parsed
# 14/21 urls of product 12 parsed
# 15/21 urls of product 12 parsed
# 16/21 urls of product 12 parsed
# 17/21 urls of product 12 parsed
# 18/21 urls of product 12 parsed
# 19/21 urls of product 12 parsed
# 20/21 urls of product 12 parsed
# 21/21 urls of product 12 parsed
# 12/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 13 parsed
# 2/21 urls of product 13 parsed
# 3/21 urls of product 13 parsed
# 4/21 urls of product 13 parsed
# 5/21 urls of product 13 parsed
# 6/21 urls of product 13 parsed
# 7/21 urls of product 13 parsed
# 8/21 urls of product 13 parsed
# 9/21 urls of product 13 parsed
# 10/21 urls of product 13 parsed
# 11/21 urls of product 13 parsed
# 12/21 urls of product 13 parsed
# 13/21 urls of product 13 parsed
# 14/21 urls of product 13 parsed
# 15/21 urls of product 13 parsed
# 16/21 urls of product 13 parsed
# 17/21 urls of product 13 parsed
# 18/21 urls of product 13 parsed
# 19/21 urls of product 13 parsed
# 20/21 urls of product 13 parsed
# 21/21 urls of product 13 parsed
# 13/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 14 parsed
# 2/21 urls of product 14 parsed
# 3/21 urls of product 14 parsed
# 4/21 urls of product 14 parsed
# 5/21 urls of product 14 parsed
# 6/21 urls of product 14 parsed
# 7/21 urls of product 14 parsed
# 8/21 urls of product 14 parsed
# 9/21 urls of product 14 parsed
# 10/21 urls of product 14 parsed
# 11/21 urls of product 14 parsed
# 12/21 urls of product 14 parsed
# 13/21 urls of product 14 parsed
# 14/21 urls of product 14 parsed
# 15/21 urls of product 14 parsed
# 16/21 urls of product 14 parsed
# 17/21 urls of product 14 parsed
# 18/21 urls of product 14 parsed
# 19/21 urls of product 14 parsed
# 20/21 urls of product 14 parsed
# 21/21 urls of product 14 parsed
# 14/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 15 parsed
# 2/21 urls of product 15 parsed
# 3/21 urls of product 15 parsed
# 4/21 urls of product 15 parsed
# 5/21 urls of product 15 parsed
# 6/21 urls of product 15 parsed
# 7/21 urls of product 15 parsed
# 8/21 urls of product 15 parsed
# 9/21 urls of product 15 parsed
# 10/21 urls of product 15 parsed
# 11/21 urls of product 15 parsed
# 12/21 urls of product 15 parsed
# 13/21 urls of product 15 parsed
# 14/21 urls of product 15 parsed
# 15/21 urls of product 15 parsed
# 16/21 urls of product 15 parsed
# 17/21 urls of product 15 parsed
# 18/21 urls of product 15 parsed
# 19/21 urls of product 15 parsed
# 20/21 urls of product 15 parsed
# 21/21 urls of product 15 parsed
# 15/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 16 parsed
# 2/21 urls of product 16 parsed
# 3/21 urls of product 16 parsed
# 4/21 urls of product 16 parsed
# 5/21 urls of product 16 parsed
# 6/21 urls of product 16 parsed
# 7/21 urls of product 16 parsed
# 8/21 urls of product 16 parsed
# 9/21 urls of product 16 parsed
# 10/21 urls of product 16 parsed
# 11/21 urls of product 16 parsed
# 12/21 urls of product 16 parsed
# 13/21 urls of product 16 parsed
# 14/21 urls of product 16 parsed
# 15/21 urls of product 16 parsed
# 16/21 urls of product 16 parsed
# 17/21 urls of product 16 parsed
# 18/21 urls of product 16 parsed
# 19/21 urls of product 16 parsed
# 20/21 urls of product 16 parsed
# 21/21 urls of product 16 parsed
# 16/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 17 parsed
# 2/21 urls of product 17 parsed
# 3/21 urls of product 17 parsed
# 4/21 urls of product 17 parsed
# 5/21 urls of product 17 parsed
# 6/21 urls of product 17 parsed
# 7/21 urls of product 17 parsed
# 8/21 urls of product 17 parsed
# 9/21 urls of product 17 parsed
# 10/21 urls of product 17 parsed
# 11/21 urls of product 17 parsed
# 12/21 urls of product 17 parsed
# 13/21 urls of product 17 parsed
# 14/21 urls of product 17 parsed
# 15/21 urls of product 17 parsed
# 16/21 urls of product 17 parsed
# 17/21 urls of product 17 parsed
# 18/21 urls of product 17 parsed
# 19/21 urls of product 17 parsed
# 20/21 urls of product 17 parsed
# 21/21 urls of product 17 parsed
# 17/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 18 parsed
# 2/21 urls of product 18 parsed
# 3/21 urls of product 18 parsed
# 4/21 urls of product 18 parsed
# 5/21 urls of product 18 parsed
# 6/21 urls of product 18 parsed
# 7/21 urls of product 18 parsed
# 8/21 urls of product 18 parsed
# 9/21 urls of product 18 parsed
# 10/21 urls of product 18 parsed
# 11/21 urls of product 18 parsed
# 12/21 urls of product 18 parsed
# 13/21 urls of product 18 parsed
# 14/21 urls of product 18 parsed
# 15/21 urls of product 18 parsed
# 16/21 urls of product 18 parsed
# 17/21 urls of product 18 parsed
# 18/21 urls of product 18 parsed
# 19/21 urls of product 18 parsed
# 20/21 urls of product 18 parsed
# 21/21 urls of product 18 parsed
# 18/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 19 parsed
# 2/21 urls of product 19 parsed
# 3/21 urls of product 19 parsed
# 4/21 urls of product 19 parsed
# 5/21 urls of product 19 parsed
# 6/21 urls of product 19 parsed
# 7/21 urls of product 19 parsed
# 8/21 urls of product 19 parsed
# 9/21 urls of product 19 parsed
# 10/21 urls of product 19 parsed
# 11/21 urls of product 19 parsed
# 12/21 urls of product 19 parsed
# 13/21 urls of product 19 parsed
# 14/21 urls of product 19 parsed
# 15/21 urls of product 19 parsed
# 16/21 urls of product 19 parsed
# 17/21 urls of product 19 parsed
# 18/21 urls of product 19 parsed
# 19/21 urls of product 19 parsed
# 20/21 urls of product 19 parsed
# 21/21 urls of product 19 parsed
# 19/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 20 parsed
# 2/21 urls of product 20 parsed
# 3/21 urls of product 20 parsed
# 4/21 urls of product 20 parsed
# 5/21 urls of product 20 parsed
# 6/21 urls of product 20 parsed
# 7/21 urls of product 20 parsed
# 8/21 urls of product 20 parsed
# 9/21 urls of product 20 parsed
# 10/21 urls of product 20 parsed
# 11/21 urls of product 20 parsed
# 12/21 urls of product 20 parsed
# 13/21 urls of product 20 parsed
# 14/21 urls of product 20 parsed
# 15/21 urls of product 20 parsed
# 16/21 urls of product 20 parsed
# 17/21 urls of product 20 parsed
# 18/21 urls of product 20 parsed
# 19/21 urls of product 20 parsed
# 20/21 urls of product 20 parsed
# 21/21 urls of product 20 parsed
# 20/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 21 parsed
# 2/21 urls of product 21 parsed
# 3/21 urls of product 21 parsed
# 4/21 urls of product 21 parsed
# 5/21 urls of product 21 parsed
# 6/21 urls of product 21 parsed
# 7/21 urls of product 21 parsed
# 8/21 urls of product 21 parsed
# 9/21 urls of product 21 parsed
# 10/21 urls of product 21 parsed
# 11/21 urls of product 21 parsed
# 12/21 urls of product 21 parsed
# 13/21 urls of product 21 parsed
# 14/21 urls of product 21 parsed
# 15/21 urls of product 21 parsed
# 16/21 urls of product 21 parsed
# 17/21 urls of product 21 parsed
# 18/21 urls of product 21 parsed
# 19/21 urls of product 21 parsed
# 20/21 urls of product 21 parsed
# 21/21 urls of product 21 parsed
# 21/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 22 parsed
# 2/21 urls of product 22 parsed
# 3/21 urls of product 22 parsed
# 4/21 urls of product 22 parsed
# 5/21 urls of product 22 parsed
# 6/21 urls of product 22 parsed
# 7/21 urls of product 22 parsed
# 8/21 urls of product 22 parsed
# 9/21 urls of product 22 parsed
# 10/21 urls of product 22 parsed
# 11/21 urls of product 22 parsed
# 12/21 urls of product 22 parsed
# 13/21 urls of product 22 parsed
# 14/21 urls of product 22 parsed
# 15/21 urls of product 22 parsed
# 16/21 urls of product 22 parsed
# 17/21 urls of product 22 parsed
# 18/21 urls of product 22 parsed
# 19/21 urls of product 22 parsed
# 20/21 urls of product 22 parsed
# 21/21 urls of product 22 parsed
# 22/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 23 parsed
# 2/21 urls of product 23 parsed
# 3/21 urls of product 23 parsed
# 4/21 urls of product 23 parsed
# 5/21 urls of product 23 parsed
# 6/21 urls of product 23 parsed
# 7/21 urls of product 23 parsed
# 8/21 urls of product 23 parsed
# 9/21 urls of product 23 parsed
# 10/21 urls of product 23 parsed
# 11/21 urls of product 23 parsed
# 12/21 urls of product 23 parsed
# 13/21 urls of product 23 parsed
# 14/21 urls of product 23 parsed
# 15/21 urls of product 23 parsed
# 16/21 urls of product 23 parsed
# 17/21 urls of product 23 parsed
# 18/21 urls of product 23 parsed
# 19/21 urls of product 23 parsed
# 20/21 urls of product 23 parsed
# 21/21 urls of product 23 parsed
# 23/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 24 parsed
# 2/21 urls of product 24 parsed
# 3/21 urls of product 24 parsed
# 4/21 urls of product 24 parsed
# 5/21 urls of product 24 parsed
# 6/21 urls of product 24 parsed
# 7/21 urls of product 24 parsed
# 8/21 urls of product 24 parsed
# 9/21 urls of product 24 parsed
# 10/21 urls of product 24 parsed
# 11/21 urls of product 24 parsed
# 12/21 urls of product 24 parsed
# 13/21 urls of product 24 parsed
# 14/21 urls of product 24 parsed
# 15/21 urls of product 24 parsed
# 16/21 urls of product 24 parsed
# 17/21 urls of product 24 parsed
# 18/21 urls of product 24 parsed
# 19/21 urls of product 24 parsed
# 20/21 urls of product 24 parsed
# 21/21 urls of product 24 parsed
# 24/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 25 parsed
# 2/21 urls of product 25 parsed
# 3/21 urls of product 25 parsed
# 4/21 urls of product 25 parsed
# 5/21 urls of product 25 parsed
# 6/21 urls of product 25 parsed
# 7/21 urls of product 25 parsed
# 8/21 urls of product 25 parsed
# 9/21 urls of product 25 parsed
# 10/21 urls of product 25 parsed
# 11/21 urls of product 25 parsed
# 12/21 urls of product 25 parsed
# 13/21 urls of product 25 parsed
# 14/21 urls of product 25 parsed
# 15/21 urls of product 25 parsed
# 16/21 urls of product 25 parsed
# 17/21 urls of product 25 parsed
# 18/21 urls of product 25 parsed
# 19/21 urls of product 25 parsed
# 20/21 urls of product 25 parsed
# 21/21 urls of product 25 parsed
# 25/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 26 parsed
# 2/21 urls of product 26 parsed
# 3/21 urls of product 26 parsed
# 4/21 urls of product 26 parsed
# 5/21 urls of product 26 parsed
# 6/21 urls of product 26 parsed
# 7/21 urls of product 26 parsed
# 8/21 urls of product 26 parsed
# 9/21 urls of product 26 parsed
# 10/21 urls of product 26 parsed
# 11/21 urls of product 26 parsed
# 12/21 urls of product 26 parsed
# 13/21 urls of product 26 parsed
# 14/21 urls of product 26 parsed
# 15/21 urls of product 26 parsed
# 16/21 urls of product 26 parsed
# 17/21 urls of product 26 parsed
# 18/21 urls of product 26 parsed
# 19/21 urls of product 26 parsed
# 20/21 urls of product 26 parsed
# 21/21 urls of product 26 parsed
# 26/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 27 parsed
# 2/21 urls of product 27 parsed
# 3/21 urls of product 27 parsed
# 4/21 urls of product 27 parsed
# 5/21 urls of product 27 parsed
# 6/21 urls of product 27 parsed
# 7/21 urls of product 27 parsed
# 8/21 urls of product 27 parsed
# 9/21 urls of product 27 parsed
# 10/21 urls of product 27 parsed
# 11/21 urls of product 27 parsed
# 12/21 urls of product 27 parsed
# 13/21 urls of product 27 parsed
# 14/21 urls of product 27 parsed
# 15/21 urls of product 27 parsed
# 16/21 urls of product 27 parsed
# 17/21 urls of product 27 parsed
# 18/21 urls of product 27 parsed
# 19/21 urls of product 27 parsed
# 20/21 urls of product 27 parsed
# 21/21 urls of product 27 parsed
# 27/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 28 parsed
# 2/21 urls of product 28 parsed
# 3/21 urls of product 28 parsed
# 4/21 urls of product 28 parsed
# 5/21 urls of product 28 parsed
# 6/21 urls of product 28 parsed
# 7/21 urls of product 28 parsed
# 8/21 urls of product 28 parsed
# 9/21 urls of product 28 parsed
# 10/21 urls of product 28 parsed
# 11/21 urls of product 28 parsed
# 12/21 urls of product 28 parsed
# 13/21 urls of product 28 parsed
# 14/21 urls of product 28 parsed
# 15/21 urls of product 28 parsed
# 16/21 urls of product 28 parsed
# 17/21 urls of product 28 parsed
# 18/21 urls of product 28 parsed
# 19/21 urls of product 28 parsed
# 20/21 urls of product 28 parsed
# 21/21 urls of product 28 parsed
# 28/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 29 parsed
# 2/21 urls of product 29 parsed
# 3/21 urls of product 29 parsed
# 4/21 urls of product 29 parsed
# 5/21 urls of product 29 parsed
# 6/21 urls of product 29 parsed
# 7/21 urls of product 29 parsed
# 8/21 urls of product 29 parsed
# 9/21 urls of product 29 parsed
# 10/21 urls of product 29 parsed
# 11/21 urls of product 29 parsed
# 12/21 urls of product 29 parsed
# 13/21 urls of product 29 parsed
# 14/21 urls of product 29 parsed
# 15/21 urls of product 29 parsed
# 16/21 urls of product 29 parsed
# 17/21 urls of product 29 parsed
# 18/21 urls of product 29 parsed
# 19/21 urls of product 29 parsed
# 20/21 urls of product 29 parsed
# 21/21 urls of product 29 parsed
# 29/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 30 parsed
# 2/21 urls of product 30 parsed
# 3/21 urls of product 30 parsed
# 4/21 urls of product 30 parsed
# 5/21 urls of product 30 parsed
# 6/21 urls of product 30 parsed
# 7/21 urls of product 30 parsed
# 8/21 urls of product 30 parsed
# 9/21 urls of product 30 parsed
# 10/21 urls of product 30 parsed
# 11/21 urls of product 30 parsed
# 12/21 urls of product 30 parsed
# 13/21 urls of product 30 parsed
# 14/21 urls of product 30 parsed
# 15/21 urls of product 30 parsed
# 16/21 urls of product 30 parsed
# 17/21 urls of product 30 parsed
# 18/21 urls of product 30 parsed
# 19/21 urls of product 30 parsed
# 20/21 urls of product 30 parsed
# 21/21 urls of product 30 parsed
# 30/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 31 parsed
# 2/21 urls of product 31 parsed
# 3/21 urls of product 31 parsed
# 4/21 urls of product 31 parsed
# 5/21 urls of product 31 parsed
# 6/21 urls of product 31 parsed
# 7/21 urls of product 31 parsed
# 8/21 urls of product 31 parsed
# 9/21 urls of product 31 parsed
# 10/21 urls of product 31 parsed
# 11/21 urls of product 31 parsed
# 12/21 urls of product 31 parsed
# 13/21 urls of product 31 parsed
# 14/21 urls of product 31 parsed
# 15/21 urls of product 31 parsed
# 16/21 urls of product 31 parsed
# 17/21 urls of product 31 parsed
# 18/21 urls of product 31 parsed
# 19/21 urls of product 31 parsed
# 20/21 urls of product 31 parsed
# 21/21 urls of product 31 parsed
# 31/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 32 parsed
# 2/21 urls of product 32 parsed
# 3/21 urls of product 32 parsed
# 4/21 urls of product 32 parsed
# 5/21 urls of product 32 parsed
# 6/21 urls of product 32 parsed
# 7/21 urls of product 32 parsed
# 8/21 urls of product 32 parsed
# 9/21 urls of product 32 parsed
# 10/21 urls of product 32 parsed
# 11/21 urls of product 32 parsed
# 12/21 urls of product 32 parsed
# 13/21 urls of product 32 parsed
# 14/21 urls of product 32 parsed
# 15/21 urls of product 32 parsed
# 16/21 urls of product 32 parsed
# 17/21 urls of product 32 parsed
# 18/21 urls of product 32 parsed
# 19/21 urls of product 32 parsed
# 20/21 urls of product 32 parsed
# 21/21 urls of product 32 parsed
# 32/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 33 parsed
# 2/21 urls of product 33 parsed
# 3/21 urls of product 33 parsed
# 4/21 urls of product 33 parsed
# 5/21 urls of product 33 parsed
# 6/21 urls of product 33 parsed
# 7/21 urls of product 33 parsed
# 8/21 urls of product 33 parsed
# 9/21 urls of product 33 parsed
# 10/21 urls of product 33 parsed
# 11/21 urls of product 33 parsed
# 12/21 urls of product 33 parsed
# 13/21 urls of product 33 parsed
# 14/21 urls of product 33 parsed
# 15/21 urls of product 33 parsed
# 16/21 urls of product 33 parsed
# 17/21 urls of product 33 parsed
# 18/21 urls of product 33 parsed
# 19/21 urls of product 33 parsed
# 20/21 urls of product 33 parsed
# 21/21 urls of product 33 parsed
# 33/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 34 parsed
# 2/21 urls of product 34 parsed
# 3/21 urls of product 34 parsed
# 4/21 urls of product 34 parsed
# 5/21 urls of product 34 parsed
# 6/21 urls of product 34 parsed
# 7/21 urls of product 34 parsed
# 8/21 urls of product 34 parsed
# 9/21 urls of product 34 parsed
# 10/21 urls of product 34 parsed
# 11/21 urls of product 34 parsed
# 12/21 urls of product 34 parsed
# 13/21 urls of product 34 parsed
# 14/21 urls of product 34 parsed
# 15/21 urls of product 34 parsed
# 16/21 urls of product 34 parsed
# 17/21 urls of product 34 parsed
# 18/21 urls of product 34 parsed
# 19/21 urls of product 34 parsed
# 20/21 urls of product 34 parsed
# 21/21 urls of product 34 parsed
# 34/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 35 parsed
# 2/21 urls of product 35 parsed
# 3/21 urls of product 35 parsed
# 4/21 urls of product 35 parsed
# 5/21 urls of product 35 parsed
# 6/21 urls of product 35 parsed
# 7/21 urls of product 35 parsed
# 8/21 urls of product 35 parsed
# 9/21 urls of product 35 parsed
# 10/21 urls of product 35 parsed
# 11/21 urls of product 35 parsed
# 12/21 urls of product 35 parsed
# 13/21 urls of product 35 parsed
# 14/21 urls of product 35 parsed
# 15/21 urls of product 35 parsed
# 16/21 urls of product 35 parsed
# 17/21 urls of product 35 parsed
# 18/21 urls of product 35 parsed
# 19/21 urls of product 35 parsed
# 20/21 urls of product 35 parsed
# 21/21 urls of product 35 parsed
# 35/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 36 parsed
# 2/21 urls of product 36 parsed
# 3/21 urls of product 36 parsed
# 4/21 urls of product 36 parsed
# 5/21 urls of product 36 parsed
# 6/21 urls of product 36 parsed
# 7/21 urls of product 36 parsed
# 8/21 urls of product 36 parsed
# 9/21 urls of product 36 parsed
# 10/21 urls of product 36 parsed
# 11/21 urls of product 36 parsed
# 12/21 urls of product 36 parsed
# 13/21 urls of product 36 parsed
# 14/21 urls of product 36 parsed
# 15/21 urls of product 36 parsed
# 16/21 urls of product 36 parsed
# 17/21 urls of product 36 parsed
# 18/21 urls of product 36 parsed
# 19/21 urls of product 36 parsed
# 20/21 urls of product 36 parsed
# 21/21 urls of product 36 parsed
# 36/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 37 parsed
# 2/21 urls of product 37 parsed
# 3/21 urls of product 37 parsed
# 4/21 urls of product 37 parsed
# 5/21 urls of product 37 parsed
# 6/21 urls of product 37 parsed
# 7/21 urls of product 37 parsed
# 8/21 urls of product 37 parsed
# 9/21 urls of product 37 parsed
# 10/21 urls of product 37 parsed
# 11/21 urls of product 37 parsed
# 12/21 urls of product 37 parsed
# 13/21 urls of product 37 parsed
# 14/21 urls of product 37 parsed
# 15/21 urls of product 37 parsed
# 16/21 urls of product 37 parsed
# 17/21 urls of product 37 parsed
# 18/21 urls of product 37 parsed
# 19/21 urls of product 37 parsed
# 20/21 urls of product 37 parsed
# 21/21 urls of product 37 parsed
# 37/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 38 parsed
# 2/21 urls of product 38 parsed
# 3/21 urls of product 38 parsed
# 4/21 urls of product 38 parsed
# 5/21 urls of product 38 parsed
# 6/21 urls of product 38 parsed
# 7/21 urls of product 38 parsed
# 8/21 urls of product 38 parsed
# 9/21 urls of product 38 parsed
# 10/21 urls of product 38 parsed
# 11/21 urls of product 38 parsed
# 12/21 urls of product 38 parsed
# 13/21 urls of product 38 parsed
# 14/21 urls of product 38 parsed
# 15/21 urls of product 38 parsed
# 16/21 urls of product 38 parsed
# 17/21 urls of product 38 parsed
# 18/21 urls of product 38 parsed
# 19/21 urls of product 38 parsed
# 20/21 urls of product 38 parsed
# 21/21 urls of product 38 parsed
# 38/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 39 parsed
# 2/21 urls of product 39 parsed
# 3/21 urls of product 39 parsed
# 4/21 urls of product 39 parsed
# 5/21 urls of product 39 parsed
# 6/21 urls of product 39 parsed
# 7/21 urls of product 39 parsed
# 8/21 urls of product 39 parsed
# 9/21 urls of product 39 parsed
# 10/21 urls of product 39 parsed
# 11/21 urls of product 39 parsed
# 12/21 urls of product 39 parsed
# 13/21 urls of product 39 parsed
# 14/21 urls of product 39 parsed
# 15/21 urls of product 39 parsed
# 16/21 urls of product 39 parsed
# 17/21 urls of product 39 parsed
# 18/21 urls of product 39 parsed
# 19/21 urls of product 39 parsed
# 20/21 urls of product 39 parsed
# 21/21 urls of product 39 parsed
# 39/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 40 parsed
# 2/21 urls of product 40 parsed
# 3/21 urls of product 40 parsed
# 4/21 urls of product 40 parsed
# 5/21 urls of product 40 parsed
# 6/21 urls of product 40 parsed
# 7/21 urls of product 40 parsed
# 8/21 urls of product 40 parsed
# 9/21 urls of product 40 parsed
# 10/21 urls of product 40 parsed
# 11/21 urls of product 40 parsed
# 12/21 urls of product 40 parsed
# 13/21 urls of product 40 parsed
# 14/21 urls of product 40 parsed
# 15/21 urls of product 40 parsed
# 16/21 urls of product 40 parsed
# 17/21 urls of product 40 parsed
# 18/21 urls of product 40 parsed
# 19/21 urls of product 40 parsed
# 20/21 urls of product 40 parsed
# 21/21 urls of product 40 parsed
# 40/40 products parsed, it took 0.1 minutes
# 0:04:22.377878
# 1/21 urls of product 1 parsed
# 2/21 urls of product 1 parsed
# 3/21 urls of product 1 parsed
# 4/21 urls of product 1 parsed
# 5/21 urls of product 1 parsed
# 6/21 urls of product 1 parsed
# 7/21 urls of product 1 parsed
# 8/21 urls of product 1 parsed
# 9/21 urls of product 1 parsed
# 10/21 urls of product 1 parsed
# 11/21 urls of product 1 parsed
# 12/21 urls of product 1 parsed
# 13/21 urls of product 1 parsed
# 14/21 urls of product 1 parsed
# 15/21 urls of product 1 parsed
# 16/21 urls of product 1 parsed
# 17/21 urls of product 1 parsed
# 18/21 urls of product 1 parsed
# 19/21 urls of product 1 parsed
# 20/21 urls of product 1 parsed
# 21/21 urls of product 1 parsed
# 1/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 2 parsed
# 2/21 urls of product 2 parsed
# 3/21 urls of product 2 parsed
# 4/21 urls of product 2 parsed
# 5/21 urls of product 2 parsed
# 6/21 urls of product 2 parsed
# 7/21 urls of product 2 parsed
# 8/21 urls of product 2 parsed
# 9/21 urls of product 2 parsed
# 10/21 urls of product 2 parsed
# 11/21 urls of product 2 parsed
# 12/21 urls of product 2 parsed
# 13/21 urls of product 2 parsed
# 14/21 urls of product 2 parsed
# 15/21 urls of product 2 parsed
# 16/21 urls of product 2 parsed
# 17/21 urls of product 2 parsed
# 18/21 urls of product 2 parsed
# 19/21 urls of product 2 parsed
# 20/21 urls of product 2 parsed
# 21/21 urls of product 2 parsed
# 2/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 3 parsed
# 2/21 urls of product 3 parsed
# 3/21 urls of product 3 parsed
# 4/21 urls of product 3 parsed
# 5/21 urls of product 3 parsed
# 6/21 urls of product 3 parsed
# 7/21 urls of product 3 parsed
# 8/21 urls of product 3 parsed
# 9/21 urls of product 3 parsed
# 10/21 urls of product 3 parsed
# 11/21 urls of product 3 parsed
# 12/21 urls of product 3 parsed
# 13/21 urls of product 3 parsed
# 14/21 urls of product 3 parsed
# 15/21 urls of product 3 parsed
# 16/21 urls of product 3 parsed
# 17/21 urls of product 3 parsed
# 18/21 urls of product 3 parsed
# 19/21 urls of product 3 parsed
# 20/21 urls of product 3 parsed
# 21/21 urls of product 3 parsed
# 3/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 4 parsed
# 2/21 urls of product 4 parsed
# 3/21 urls of product 4 parsed
# 4/21 urls of product 4 parsed
# 5/21 urls of product 4 parsed
# 6/21 urls of product 4 parsed
# 7/21 urls of product 4 parsed
# 8/21 urls of product 4 parsed
# 9/21 urls of product 4 parsed
# 10/21 urls of product 4 parsed
# 11/21 urls of product 4 parsed
# 12/21 urls of product 4 parsed
# 13/21 urls of product 4 parsed
# 14/21 urls of product 4 parsed
# 15/21 urls of product 4 parsed
# 16/21 urls of product 4 parsed
# 17/21 urls of product 4 parsed
# 18/21 urls of product 4 parsed
# 19/21 urls of product 4 parsed
# 20/21 urls of product 4 parsed
# 21/21 urls of product 4 parsed
# 4/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 5 parsed
# 2/21 urls of product 5 parsed
# 3/21 urls of product 5 parsed
# 4/21 urls of product 5 parsed
# 5/21 urls of product 5 parsed
# 6/21 urls of product 5 parsed
# 7/21 urls of product 5 parsed
# 8/21 urls of product 5 parsed
# 9/21 urls of product 5 parsed
# 10/21 urls of product 5 parsed
# 11/21 urls of product 5 parsed
# 12/21 urls of product 5 parsed
# 13/21 urls of product 5 parsed
# 14/21 urls of product 5 parsed
# 15/21 urls of product 5 parsed
# 16/21 urls of product 5 parsed
# 17/21 urls of product 5 parsed
# 18/21 urls of product 5 parsed
# 19/21 urls of product 5 parsed
# 20/21 urls of product 5 parsed
# 21/21 urls of product 5 parsed
# 5/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 6 parsed
# 2/21 urls of product 6 parsed
# 3/21 urls of product 6 parsed
# 4/21 urls of product 6 parsed
# 5/21 urls of product 6 parsed
# 6/21 urls of product 6 parsed
# 7/21 urls of product 6 parsed
# 8/21 urls of product 6 parsed
# 9/21 urls of product 6 parsed
# 10/21 urls of product 6 parsed
# 11/21 urls of product 6 parsed
# 12/21 urls of product 6 parsed
# 13/21 urls of product 6 parsed
# 14/21 urls of product 6 parsed
# 15/21 urls of product 6 parsed
# 16/21 urls of product 6 parsed
# 17/21 urls of product 6 parsed
# 18/21 urls of product 6 parsed
# 19/21 urls of product 6 parsed
# 20/21 urls of product 6 parsed
# 21/21 urls of product 6 parsed
# 6/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 7 parsed
# 2/21 urls of product 7 parsed
# 3/21 urls of product 7 parsed
# 4/21 urls of product 7 parsed
# 5/21 urls of product 7 parsed
# 6/21 urls of product 7 parsed
# 7/21 urls of product 7 parsed
# 8/21 urls of product 7 parsed
# 9/21 urls of product 7 parsed
# 10/21 urls of product 7 parsed
# 11/21 urls of product 7 parsed
# 12/21 urls of product 7 parsed
# 13/21 urls of product 7 parsed
# 14/21 urls of product 7 parsed
# 15/21 urls of product 7 parsed
# 16/21 urls of product 7 parsed
# 17/21 urls of product 7 parsed
# 18/21 urls of product 7 parsed
# 19/21 urls of product 7 parsed
# 20/21 urls of product 7 parsed
# 21/21 urls of product 7 parsed
# 7/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 8 parsed
# 2/21 urls of product 8 parsed
# 3/21 urls of product 8 parsed
# 4/21 urls of product 8 parsed
# 5/21 urls of product 8 parsed
# 6/21 urls of product 8 parsed
# 7/21 urls of product 8 parsed
# 8/21 urls of product 8 parsed
# 9/21 urls of product 8 parsed
# 10/21 urls of product 8 parsed
# 11/21 urls of product 8 parsed
# 12/21 urls of product 8 parsed
# 13/21 urls of product 8 parsed
# 14/21 urls of product 8 parsed
# 15/21 urls of product 8 parsed
# 16/21 urls of product 8 parsed
# 17/21 urls of product 8 parsed
# 18/21 urls of product 8 parsed
# 19/21 urls of product 8 parsed
# 20/21 urls of product 8 parsed
# 21/21 urls of product 8 parsed
# 8/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 9 parsed
# 2/21 urls of product 9 parsed
# 3/21 urls of product 9 parsed
# 4/21 urls of product 9 parsed
# 5/21 urls of product 9 parsed
# 6/21 urls of product 9 parsed
# 7/21 urls of product 9 parsed
# 8/21 urls of product 9 parsed
# 9/21 urls of product 9 parsed
# 10/21 urls of product 9 parsed
# 11/21 urls of product 9 parsed
# 12/21 urls of product 9 parsed
# 13/21 urls of product 9 parsed
# 14/21 urls of product 9 parsed
# 15/21 urls of product 9 parsed
# 16/21 urls of product 9 parsed
# 17/21 urls of product 9 parsed
# 18/21 urls of product 9 parsed
# 19/21 urls of product 9 parsed
# 20/21 urls of product 9 parsed
# 21/21 urls of product 9 parsed
# 9/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 10 parsed
# 2/21 urls of product 10 parsed
# 3/21 urls of product 10 parsed
# 4/21 urls of product 10 parsed
# 5/21 urls of product 10 parsed
# 6/21 urls of product 10 parsed
# 7/21 urls of product 10 parsed
# 8/21 urls of product 10 parsed
# 9/21 urls of product 10 parsed
# 10/21 urls of product 10 parsed
# 11/21 urls of product 10 parsed
# 12/21 urls of product 10 parsed
# 13/21 urls of product 10 parsed
# 14/21 urls of product 10 parsed
# 15/21 urls of product 10 parsed
# 16/21 urls of product 10 parsed
# 17/21 urls of product 10 parsed
# 18/21 urls of product 10 parsed
# 19/21 urls of product 10 parsed
# 20/21 urls of product 10 parsed
# 21/21 urls of product 10 parsed
# 10/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 11 parsed
# 2/21 urls of product 11 parsed
# 3/21 urls of product 11 parsed
# 4/21 urls of product 11 parsed
# 5/21 urls of product 11 parsed
# 6/21 urls of product 11 parsed
# 7/21 urls of product 11 parsed
# 8/21 urls of product 11 parsed
# 9/21 urls of product 11 parsed
# 10/21 urls of product 11 parsed
# 11/21 urls of product 11 parsed
# 12/21 urls of product 11 parsed
# 13/21 urls of product 11 parsed
# 14/21 urls of product 11 parsed
# 15/21 urls of product 11 parsed
# 16/21 urls of product 11 parsed
# 17/21 urls of product 11 parsed
# 18/21 urls of product 11 parsed
# 19/21 urls of product 11 parsed
# 20/21 urls of product 11 parsed
# 21/21 urls of product 11 parsed
# 11/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 12 parsed
# 2/21 urls of product 12 parsed
# 3/21 urls of product 12 parsed
# 4/21 urls of product 12 parsed
# 5/21 urls of product 12 parsed
# 6/21 urls of product 12 parsed
# 7/21 urls of product 12 parsed
# 8/21 urls of product 12 parsed
# 9/21 urls of product 12 parsed
# 10/21 urls of product 12 parsed
# 11/21 urls of product 12 parsed
# 12/21 urls of product 12 parsed
# 13/21 urls of product 12 parsed
# 14/21 urls of product 12 parsed
# 15/21 urls of product 12 parsed
# 16/21 urls of product 12 parsed
# 17/21 urls of product 12 parsed
# 18/21 urls of product 12 parsed
# 19/21 urls of product 12 parsed
# 20/21 urls of product 12 parsed
# 21/21 urls of product 12 parsed
# 12/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 13 parsed
# 2/21 urls of product 13 parsed
# 3/21 urls of product 13 parsed
# 4/21 urls of product 13 parsed
# 5/21 urls of product 13 parsed
# 6/21 urls of product 13 parsed
# 7/21 urls of product 13 parsed
# 8/21 urls of product 13 parsed
# 9/21 urls of product 13 parsed
# 10/21 urls of product 13 parsed
# 11/21 urls of product 13 parsed
# 12/21 urls of product 13 parsed
# 13/21 urls of product 13 parsed
# 14/21 urls of product 13 parsed
# 15/21 urls of product 13 parsed
# 16/21 urls of product 13 parsed
# 17/21 urls of product 13 parsed
# 18/21 urls of product 13 parsed
# 19/21 urls of product 13 parsed
# 20/21 urls of product 13 parsed
# 21/21 urls of product 13 parsed
# 13/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 14 parsed
# 2/21 urls of product 14 parsed
# 3/21 urls of product 14 parsed
# 4/21 urls of product 14 parsed
# 5/21 urls of product 14 parsed
# 6/21 urls of product 14 parsed
# 7/21 urls of product 14 parsed
# 8/21 urls of product 14 parsed
# 9/21 urls of product 14 parsed
# 10/21 urls of product 14 parsed
# 11/21 urls of product 14 parsed
# 12/21 urls of product 14 parsed
# 13/21 urls of product 14 parsed
# 14/21 urls of product 14 parsed
# 15/21 urls of product 14 parsed
# 16/21 urls of product 14 parsed
# 17/21 urls of product 14 parsed
# 18/21 urls of product 14 parsed
# 19/21 urls of product 14 parsed
# 20/21 urls of product 14 parsed
# 21/21 urls of product 14 parsed
# 14/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 15 parsed
# 2/21 urls of product 15 parsed
# 3/21 urls of product 15 parsed
# 4/21 urls of product 15 parsed
# 5/21 urls of product 15 parsed
# 6/21 urls of product 15 parsed
# 7/21 urls of product 15 parsed
# 8/21 urls of product 15 parsed
# 9/21 urls of product 15 parsed
# 10/21 urls of product 15 parsed
# 11/21 urls of product 15 parsed
# 12/21 urls of product 15 parsed
# 13/21 urls of product 15 parsed
# 14/21 urls of product 15 parsed
# 15/21 urls of product 15 parsed
# 16/21 urls of product 15 parsed
# 17/21 urls of product 15 parsed
# 18/21 urls of product 15 parsed
# 19/21 urls of product 15 parsed
# 20/21 urls of product 15 parsed
# 21/21 urls of product 15 parsed
# 15/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 16 parsed
# 2/21 urls of product 16 parsed
# 3/21 urls of product 16 parsed
# 4/21 urls of product 16 parsed
# 5/21 urls of product 16 parsed
# 6/21 urls of product 16 parsed
# 7/21 urls of product 16 parsed
# 8/21 urls of product 16 parsed
# 9/21 urls of product 16 parsed
# 10/21 urls of product 16 parsed
# 11/21 urls of product 16 parsed
# 12/21 urls of product 16 parsed
# 13/21 urls of product 16 parsed
# 14/21 urls of product 16 parsed
# 15/21 urls of product 16 parsed
# 16/21 urls of product 16 parsed
# 17/21 urls of product 16 parsed
# 18/21 urls of product 16 parsed
# 19/21 urls of product 16 parsed
# 20/21 urls of product 16 parsed
# 21/21 urls of product 16 parsed
# 16/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 17 parsed
# 2/21 urls of product 17 parsed
# 3/21 urls of product 17 parsed
# 4/21 urls of product 17 parsed
# 5/21 urls of product 17 parsed
# 6/21 urls of product 17 parsed
# 7/21 urls of product 17 parsed
# 8/21 urls of product 17 parsed
# 9/21 urls of product 17 parsed
# 10/21 urls of product 17 parsed
# 11/21 urls of product 17 parsed
# 12/21 urls of product 17 parsed
# 13/21 urls of product 17 parsed
# 14/21 urls of product 17 parsed
# 15/21 urls of product 17 parsed
# 16/21 urls of product 17 parsed
# 17/21 urls of product 17 parsed
# 18/21 urls of product 17 parsed
# 19/21 urls of product 17 parsed
# 20/21 urls of product 17 parsed
# 21/21 urls of product 17 parsed
# 17/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 18 parsed
# 2/21 urls of product 18 parsed
# 3/21 urls of product 18 parsed
# 4/21 urls of product 18 parsed
# 5/21 urls of product 18 parsed
# 6/21 urls of product 18 parsed
# 7/21 urls of product 18 parsed
# 8/21 urls of product 18 parsed
# 9/21 urls of product 18 parsed
# 10/21 urls of product 18 parsed
# 11/21 urls of product 18 parsed
# 12/21 urls of product 18 parsed
# 13/21 urls of product 18 parsed
# 14/21 urls of product 18 parsed
# 15/21 urls of product 18 parsed
# 16/21 urls of product 18 parsed
# 17/21 urls of product 18 parsed
# 18/21 urls of product 18 parsed
# 19/21 urls of product 18 parsed
# 20/21 urls of product 18 parsed
# 21/21 urls of product 18 parsed
# 18/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 19 parsed
# 2/21 urls of product 19 parsed
# 3/21 urls of product 19 parsed
# 4/21 urls of product 19 parsed
# 5/21 urls of product 19 parsed
# 6/21 urls of product 19 parsed
# 7/21 urls of product 19 parsed
# 8/21 urls of product 19 parsed
# 9/21 urls of product 19 parsed
# 10/21 urls of product 19 parsed
# 11/21 urls of product 19 parsed
# 12/21 urls of product 19 parsed
# 13/21 urls of product 19 parsed
# 14/21 urls of product 19 parsed
# 15/21 urls of product 19 parsed
# 16/21 urls of product 19 parsed
# 17/21 urls of product 19 parsed
# 18/21 urls of product 19 parsed
# 19/21 urls of product 19 parsed
# 20/21 urls of product 19 parsed
# 21/21 urls of product 19 parsed
# 19/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 20 parsed
# 2/21 urls of product 20 parsed
# 3/21 urls of product 20 parsed
# 4/21 urls of product 20 parsed
# 5/21 urls of product 20 parsed
# 6/21 urls of product 20 parsed
# 7/21 urls of product 20 parsed
# 8/21 urls of product 20 parsed
# 9/21 urls of product 20 parsed
# 10/21 urls of product 20 parsed
# 11/21 urls of product 20 parsed
# 12/21 urls of product 20 parsed
# 13/21 urls of product 20 parsed
# 14/21 urls of product 20 parsed
# 15/21 urls of product 20 parsed
# 16/21 urls of product 20 parsed
# 17/21 urls of product 20 parsed
# 18/21 urls of product 20 parsed
# 19/21 urls of product 20 parsed
# 20/21 urls of product 20 parsed
# 21/21 urls of product 20 parsed
# 20/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 21 parsed
# 2/21 urls of product 21 parsed
# 3/21 urls of product 21 parsed
# 4/21 urls of product 21 parsed
# 5/21 urls of product 21 parsed
# 6/21 urls of product 21 parsed
# 7/21 urls of product 21 parsed
# 8/21 urls of product 21 parsed
# 9/21 urls of product 21 parsed
# 10/21 urls of product 21 parsed
# 11/21 urls of product 21 parsed
# 12/21 urls of product 21 parsed
# 13/21 urls of product 21 parsed
# 14/21 urls of product 21 parsed
# 15/21 urls of product 21 parsed
# 16/21 urls of product 21 parsed
# 17/21 urls of product 21 parsed
# 18/21 urls of product 21 parsed
# 19/21 urls of product 21 parsed
# 20/21 urls of product 21 parsed
# 21/21 urls of product 21 parsed
# 21/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 22 parsed
# 2/21 urls of product 22 parsed
# 3/21 urls of product 22 parsed
# 4/21 urls of product 22 parsed
# 5/21 urls of product 22 parsed
# 6/21 urls of product 22 parsed
# 7/21 urls of product 22 parsed
# 8/21 urls of product 22 parsed
# 9/21 urls of product 22 parsed
# 10/21 urls of product 22 parsed
# 11/21 urls of product 22 parsed
# 12/21 urls of product 22 parsed
# 13/21 urls of product 22 parsed
# 14/21 urls of product 22 parsed
# 15/21 urls of product 22 parsed
# 16/21 urls of product 22 parsed
# 17/21 urls of product 22 parsed
# 18/21 urls of product 22 parsed
# 19/21 urls of product 22 parsed
# 20/21 urls of product 22 parsed
# 21/21 urls of product 22 parsed
# 22/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 23 parsed
# 2/21 urls of product 23 parsed
# 3/21 urls of product 23 parsed
# 4/21 urls of product 23 parsed
# 5/21 urls of product 23 parsed
# 6/21 urls of product 23 parsed
# 7/21 urls of product 23 parsed
# 8/21 urls of product 23 parsed
# 9/21 urls of product 23 parsed
# 10/21 urls of product 23 parsed
# 11/21 urls of product 23 parsed
# 12/21 urls of product 23 parsed
# 13/21 urls of product 23 parsed
# 14/21 urls of product 23 parsed
# 15/21 urls of product 23 parsed
# 16/21 urls of product 23 parsed
# 17/21 urls of product 23 parsed
# 18/21 urls of product 23 parsed
# 19/21 urls of product 23 parsed
# 20/21 urls of product 23 parsed
# 21/21 urls of product 23 parsed
# 23/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 24 parsed
# 2/21 urls of product 24 parsed
# 3/21 urls of product 24 parsed
# 4/21 urls of product 24 parsed
# 5/21 urls of product 24 parsed
# 6/21 urls of product 24 parsed
# 7/21 urls of product 24 parsed
# 8/21 urls of product 24 parsed
# 9/21 urls of product 24 parsed
# 10/21 urls of product 24 parsed
# 11/21 urls of product 24 parsed
# 12/21 urls of product 24 parsed
# 13/21 urls of product 24 parsed
# 14/21 urls of product 24 parsed
# 15/21 urls of product 24 parsed
# 16/21 urls of product 24 parsed
# 17/21 urls of product 24 parsed
# 18/21 urls of product 24 parsed
# 19/21 urls of product 24 parsed
# 20/21 urls of product 24 parsed
# 21/21 urls of product 24 parsed
# 24/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 25 parsed
# 2/21 urls of product 25 parsed
# 3/21 urls of product 25 parsed
# 4/21 urls of product 25 parsed
# 5/21 urls of product 25 parsed
# 6/21 urls of product 25 parsed
# 7/21 urls of product 25 parsed
# 8/21 urls of product 25 parsed
# 9/21 urls of product 25 parsed
# 10/21 urls of product 25 parsed
# 11/21 urls of product 25 parsed
# 12/21 urls of product 25 parsed
# 13/21 urls of product 25 parsed
# 14/21 urls of product 25 parsed
# 15/21 urls of product 25 parsed
# 16/21 urls of product 25 parsed
# 17/21 urls of product 25 parsed
# 18/21 urls of product 25 parsed
# 19/21 urls of product 25 parsed
# 20/21 urls of product 25 parsed
# 21/21 urls of product 25 parsed
# 25/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 26 parsed
# 2/21 urls of product 26 parsed
# 3/21 urls of product 26 parsed
# 4/21 urls of product 26 parsed
# 5/21 urls of product 26 parsed
# 6/21 urls of product 26 parsed
# 7/21 urls of product 26 parsed
# 8/21 urls of product 26 parsed
# 9/21 urls of product 26 parsed
# 10/21 urls of product 26 parsed
# 11/21 urls of product 26 parsed
# 12/21 urls of product 26 parsed
# 13/21 urls of product 26 parsed
# 14/21 urls of product 26 parsed
# 15/21 urls of product 26 parsed
# 16/21 urls of product 26 parsed
# 17/21 urls of product 26 parsed
# 18/21 urls of product 26 parsed
# 19/21 urls of product 26 parsed
# 20/21 urls of product 26 parsed
# 21/21 urls of product 26 parsed
# 26/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 27 parsed
# 2/21 urls of product 27 parsed
# 3/21 urls of product 27 parsed
# 4/21 urls of product 27 parsed
# 5/21 urls of product 27 parsed
# 6/21 urls of product 27 parsed
# 7/21 urls of product 27 parsed
# 8/21 urls of product 27 parsed
# 9/21 urls of product 27 parsed
# 10/21 urls of product 27 parsed
# 11/21 urls of product 27 parsed
# 12/21 urls of product 27 parsed
# 13/21 urls of product 27 parsed
# 14/21 urls of product 27 parsed
# 15/21 urls of product 27 parsed
# 16/21 urls of product 27 parsed
# 17/21 urls of product 27 parsed
# 18/21 urls of product 27 parsed
# 19/21 urls of product 27 parsed
# 20/21 urls of product 27 parsed
# 21/21 urls of product 27 parsed
# 27/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 28 parsed
# 2/21 urls of product 28 parsed
# 3/21 urls of product 28 parsed
# 4/21 urls of product 28 parsed
# 5/21 urls of product 28 parsed
# 6/21 urls of product 28 parsed
# 7/21 urls of product 28 parsed
# 8/21 urls of product 28 parsed
# 9/21 urls of product 28 parsed
# 10/21 urls of product 28 parsed
# 11/21 urls of product 28 parsed
# 12/21 urls of product 28 parsed
# 13/21 urls of product 28 parsed
# 14/21 urls of product 28 parsed
# 15/21 urls of product 28 parsed
# 16/21 urls of product 28 parsed
# 17/21 urls of product 28 parsed
# 18/21 urls of product 28 parsed
# 19/21 urls of product 28 parsed
# 20/21 urls of product 28 parsed
# 21/21 urls of product 28 parsed
# 28/40 products parsed, it took 0.1 minutes
# 1/21 urls of product 29 parsed
# 2/21 urls of product 29 parsed
# 3/21 urls of product 29 parsed
# 4/21 urls of product 29 parsed
# 5/21 urls of product 29 parsed
# ...
# 33  {'ad_name': 'Болт ГОСТ 7785-81 с потайной голо...
# 34  {'ad_name': 'Болт ГОСТ 7817-80 с уменьшенной г...
# 35  {'ad_name': 'Болт А2 М 8х40 нержавеющая сталь ...
# 36  {'ad_name': 'Болт А2 М 8х20 нержавеющая сталь ...
# 37  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 38  {'ad_name': 'Болт М 10х16 ГОСТ 7805 (кг)', 'ur...
# 39  {'ad_name': 'Болт М 12х35 ГОСТ 7805 (кг)', 'ur...
# 40  {'ad_name': 'Болт А4 М 6х30 нержавеющая сталь ...
# 41  {'ad_name': 'Болт М 8х105 цинк ГОСТ 7805 (кг)'...
# 42  {'ad_name': 'Болт А2 М 8х25 нержавеющая сталь ...
# 43  {'ad_name': 'Болт А2 М 6х30 нержавеющая сталь ...
#
#                                             ГОСТ 7808  \
# 0                                                 NaN
# 1                                                 NaN
# 2   {'ad_name': 'Болт с шестигранной головкой, оци...
# 3   {'ad_name': 'Гайка ГОСТ 5915-70, 5927 (в т.ч. ...
# 4   {'ad_name': 'Болт с шестигранной головкой, оци...
# 5   {'ad_name': 'Болт класс прочности 8.8. ГОСТ 77...
# 6   {'ad_name': 'Болт класс прочности 5.8 ГОСТ 779...
# 7   {'ad_name': 'Болт с шестигранной головкой зубр...
# 8   {'ad_name': 'Болт с шестигранной головкой зубр...
# 9   {'ad_name': 'Шестигранная гайка зубр мастер го...
# 10  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 11  {'ad_name': 'Болт М 8х100 цинк ГОСТ 7808 (кг)'...
# 12  {'ad_name': 'Болт М 12х35 ГОСТ 7808 (кг)', 'ur...
# 13  {'ad_name': 'Болт Гост 52644-06 класс прочност...
# 14  {'ad_name': 'Новые деревянные поддоны и паллет...
# 15  {'ad_name': '"Гайка ГОСТ 10605-94 (в т.ч. клас...
# 16  {'ad_name': 'Гайка класс прочности 8.0. ГОСТ 5...
# 17  {'ad_name': 'Болты с шестигранной уменьшенной ...
# 18  {'ad_name': 'Гайка Гост 52645-06 класс прочнос...
# 19  {'ad_name': 'Шайбы высокопрочные диаметром 20-...
# 20  {'ad_name': 'Гайки высокопрочные М20-30мм клас...
# 21  {'ad_name': 'Болты высокопрочные М8-30мм класс...
# 22  {'ad_name': 'Болты высокопрочные М20-30мм клас...
# 23  {'ad_name': '"Гайка ГОСТ 5915-70, 5927 (в т.ч....
# 24  {'ad_name': '"Гайка ГОСТ 5915-70, 5927 (в т.ч....
# 25  {'ad_name': '"Гайка ГОСТ 5915-70, 5927 (в т.ч....
# 26  {'ad_name': 'Болты с шестигранной уменьшенной ...
# 27  {'ad_name': 'Болт Гост 52644-06 класс прочност...
# 28  {'ad_name': 'Болт класс прочности 5.8 ГОСТ 779...
# 29  {'ad_name': 'Болт класс прочности 8.8. ГОСТ 77...
# 30  {'ad_name': 'Болты свободные с шестигранной го...
# 31  {'ad_name': 'Болт с шестигранной головкой, оци...
# 32  {'ad_name': 'Болт с шестигранной головкой, оци...
# 33  {'ad_name': 'Высокопрочные болты ГОСТ Р52644-2...
# 34  {'ad_name': 'Болт М 8х100 цинк ГОСТ 7808 (кг)'...
# 35  {'ad_name': 'Болт ГОСТ 7808-70', 'url': 'https...
# 36  {'ad_name': 'Болт М 12х35 ГОСТ 7808 (кг)', 'ur...
# 37  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 38  {'ad_name': 'Болт анкерный  с шестигранной гол...
# 39  {'ad_name': 'Болты высокопрочные М8-30мм класс...
# 40  {'ad_name': 'Болты высокопрочные М20-30мм клас...
# 41  {'ad_name': 'Болты нержавеющие с шестигранной ...
# 42  {'ad_name': 'Болты нержавеющие с шестигранной ...
# 43  {'ad_name': 'Болт полнорезьбовой с шестигранно...
#
#                                             ГОСТ 5916  \
# 0                                                 NaN
# 1                                                 NaN
# 2   {'ad_name': 'Гайка шестигранная низкая, с фаск...
# 3   {'ad_name': 'Гайка ГОСТ 5916-70 (низкая)', 'ur...
# 4   {'ad_name': 'Гайка шестигранная, ГОСТ 5915-70,...
# 5   {'ad_name': 'Гайка шестигранная ГОСТ 5927-70, ...
# 6   {'ad_name': 'Гайка шестигранная оцинкованная М...
# 7   {'ad_name': 'Гайка шестигранная М20 кл.пр.10 Г...
# 8   {'ad_name': 'Гайка низкая ГОСТ 5916-70, 5929-7...
# 9   {'ad_name': 'DIN 934 Гайка шестигранная с круп...
# 10  {'ad_name': 'Гайка шестигранная черн. М20 кл.п...
# 11  {'ad_name': 'Гайка шестигранная ГОСТ 5915-70',...
# 12  {'ad_name': 'Гайка шестигранная низкая с умень...
# 13  {'ad_name': 'Гайка шестигранная, ГОСТ 5915-70,...
# 14  {'ad_name': 'Гайка шестигранная ГОСТ 5915-70',...
# 15  {'ad_name': 'Гайка шестигранная', 'url': 'http...
# 16  {'ad_name': 'Гайка шестигранная М10', 'url': '...
# 17  {'ad_name': 'Гайка шестигранная М8', 'url': 'h...
# 18  {'ad_name': 'Гайка шестигранная М10 HDZ IEK', ...
# 19  {'ad_name': 'Гайка шестигранная М8 HDZ IEK', '...
# 20  {'ad_name': 'Гайка шестигранная М12', 'url': '...
# 21  {'ad_name': 'Гайка шестигранная М6 HDZ IEK', '...
# 22  {'ad_name': 'Гайка шестигранная М12 HDZ IEK', ...
# 23  {'ad_name': 'Гайки шестигранные ГОСТ 5916-70',...
# 24  {'ad_name': 'Гайка шестигранная низкая, с фаск...
# 25  {'ad_name': 'Гайка шестигранная со сферическим...
# 26  {'ad_name': 'Гайка шестигранная с буртиком гос...
# 27  {'ad_name': 'Гайки по ГОСТ 5918-73, ГОСТ 5919-...
# 28  {'ad_name': 'Гайка ГОСТ 5916-70 (низкая)', 'ur...
# 29  {'ad_name': 'корончатая Гайка ГОСТ 5916-70 ,ни...
# 30  {'ad_name': 'Гайка шестигранная черн. М20 кл.п...
# 31  {'ad_name': 'Гайка шестигранная ГОСТ 5927-70, ...
# 32  {'ad_name': 'Гайки шестигранные ГОСТ 10605-94'...
# 33  {'ad_name': 'Гайки шестигранные ГОСТ 10605-94 ...
# 34  {'ad_name': 'Гайка шестигранные М24 ГОСТ Р5264...
# 35  {'ad_name': 'Гайка шестигранная М20 кл.пр.10 Г...
# 36  {'ad_name': 'Гайки шестигранные ГОСТ 5919-73',...
# 37  {'ad_name': 'Гайки шестигранные ГОСТ 5915-70, ...
# 38  {'ad_name': 'Гайки шестигранные ГОСТ 5915-70 Т...
# 39  {'ad_name': 'Гайки шестигранные ГОСТ 5927-70, ...
# 40  {'ad_name': 'Гайки шестигранные ГОСТ Р52645-20...
# 41  {'ad_name': 'Гайки шестигранные ГОСТ 5915-70',...
# 42  {'ad_name': 'DIN 934 Гайка шестигранная с круп...
# 43  {'ad_name': 'Гайки шестигранные ГОСТ 9064-75',...
#
#                                            ГОСТ 15521  \
# 0                                                 NaN
# 1                                                 NaN
# 2   {'ad_name': 'класс прочности 4.8, оцинкованная...
# 3   {'ad_name': 'Шестигранная гайка зубр мастер го...
# 4   {'ad_name': '"Гайка ГОСТ 10605-94 (в т.ч. клас...
# 5   {'ad_name': 'Гайка класс прочности 8.0. ГОСТ 5...
# 6   {'ad_name': 'Гайка ГОСТ 5915-70, 5927 (в т.ч. ...
# 7   {'ad_name': 'Гайка Гост 52645-06 класс прочнос...
# 8   {'ad_name': 'Болт с шестигранной головкой зубр...
# 9   {'ad_name': 'Болт с шестигранной головкой зубр...
# 10  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 11  {'ad_name': 'Болт Гост 52644-06 класс прочност...
# 12  {'ad_name': 'Гайка круглая шлицевая, класс точ...
# 13  {'ad_name': 'Болт класс прочности 5.8 ГОСТ 779...
# 14  {'ad_name': 'Шайбы высокопрочные диаметром 20-...
# 15  {'ad_name': 'Болты высокопрочные М8-30мм класс...
# 16  {'ad_name': 'Болты высокопрочные М20-30мм клас...
# 17  {'ad_name': 'Болт класс прочности 8.8. ГОСТ 77...
# 18  {'ad_name': 'Гайки высокопрочные М20-30мм клас...
# 19  {'ad_name': 'Арматура класс прочности III', 'u...
# 20  {'ad_name': 'Лист толстый, 17Г1С, ТУ 14-1-5241...
# 21  {'ad_name': 'Болт с шестигранной головкой, оци...
# 22  {'ad_name': 'Протяжка шпоночная поле допуска Р...
# 23  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 24  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 25  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 26  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 27  {'ad_name': '"Гайка ГОСТ 10605-94 (в т.ч. клас...
# 28  {'ad_name': '"Гайка ГОСТ 5915-70, 5927 (в т.ч....
# 29  {'ad_name': 'Гайка класс прочности 8.0. ГОСТ 5...
# 30  {'ad_name': 'Гайка Гост 52645-06 класс прочнос...
# 31  {'ad_name': 'Гайки высокопрочные М20-30мм клас...
# 32  {'ad_name': 'Гайка гост 15521-70 – 15525-70', ...
# 33  {'ad_name': 'Гайка круглая шлицевая класс точн...
# 34  {'ad_name': 'Высокопрочные болты ГОСТ Р52644-2...
# 35  {'ad_name': 'Болт класс прочности 5.8 ГОСТ 779...
# 36  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 37  {'ad_name': 'Проволока стальная пружинная ГОСТ...
# 38  {'ad_name': 'Болты высокопрочные М20-30мм клас...
# 39  {'ad_name': 'Шайбы высокопрочные диаметром 20-...
# 40  {'ad_name': 'Болт класс прочности 8.8. ГОСТ 77...
# 41  {'ad_name': 'Гайка круглая шлицевая, класс точ...
# 42  {'ad_name': 'Болты высокопрочные М8-30мм класс...
# 43  {'ad_name': 'Болт Гост 52644-06 класс прочност...
#
#                                            ГОСТ 10450  \
# 0                                                 NaN
# 1                                                 NaN
# 2   {'ad_name': 'Шайба плоская, ГОСТ 11371-80', 'u...
# 3   {'ad_name': 'Шайба плоская ГОСТ 11371-78, DIN ...
# 4   {'ad_name': 'DIN 125 Шайба плоская ISO 7089, Г...
# 5   {'ad_name': 'Шайба плоская ГОСТ 11371-70', 'ur...
# 6   {'ad_name': 'DIN 9021 Шайба плоская увеличенна...
# 7   {'ad_name': 'Шайба плоская Гост 52646-2006 выс...
# 8   {'ad_name': 'Шайба ГОСТ 10450', 'url': 'https:...
# 9   {'ad_name': 'шайба плоская ГОСТ 11371-78', 'ur...
# 10  {'ad_name': 'ГОСТ 11371-78 – шайба плоская нор...
# 11  {'ad_name': 'ГОСТ 6958-78 – шайба плоская увел...
# 12  {'ad_name': 'Шайба плоская усиленная', 'url': ...
# 13  {'ad_name': 'Шайба плоская', 'url': 'https://w...
# 14  {'ad_name': 'Шайба плоская M6 HDZ IEK', 'url':...
# 15  {'ad_name': 'Шайба плоская M8 HDZ IEK', 'url':...
# 16  {'ad_name': 'Шайба плоская M6', 'url': 'https:...
# 17  {'ad_name': 'Шайба плоская M8', 'url': 'https:...
# 18  {'ad_name': 'Шайба плоская усиленная M10 HDZ I...
# 19  {'ad_name': 'Шайба плоская M12', 'url': 'https...
# 20  {'ad_name': 'Шайба плоская M10 HDZ IEK', 'url'...
# 21  {'ad_name': 'Шайба плоская усиленная M12', 'ur...
# 22  {'ad_name': 'Шайба плоская усиленная M6 HDZ IE...
# 23  {'ad_name': 'Шайбы плоские по ГОСТ 11371, DIN ...
# 24  {'ad_name': 'Шайба плоская ГОСТ 11371-78, DIN ...
# 25  {'ad_name': 'Шайба плоская ГОСТ 11371-78 (DIN ...
# 26  {'ad_name': 'Шайба плоская ГОСТ 11371-70', 'ur...
# 27  {'ad_name': 'шайба плоская ГОСТ 11371-78', 'ur...
# 28  {'ad_name': 'Шайба плоская, ГОСТ 11371-80', 'u...
# 29  {'ad_name': 'DIN 125 Шайба плоская ISO 7089, Г...
# 30  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 31  {'ad_name': 'Шайбы плоские ГОСТ 6402-70', 'url...
# 32  {'ad_name': 'Шайба плоская М24 ГОСТ 22355-77',...
# 33  {'ad_name': 'DIN 9021 Шайба плоская увеличенна...
# 34  {'ad_name': 'Шайба плоская Гост 52646-2006 выс...
# 35  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 36  {'ad_name': 'Шайба ГОСТ 10450', 'url': 'https:...
# 37  {'ad_name': 'Шайба плоская увеличенная DIN 902...
# 38  {'ad_name': 'ГОСТ 11371-78 – шайба плоская нор...
# 39  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 40  {'ad_name': 'ГОСТ 6958-78 – шайба плоская увел...
# 41  {'ad_name': 'Шайба плоская  ГОСТ 11371', 'url'...
# 42  {'ad_name': 'Шайба плоская', 'url': 'https://w...
# 43  {'ad_name': 'Шайба плоская усиленная', 'url': ...
#
#                                             ГОСТ 6958  \
# 0                                                 NaN
# 1                                                 NaN
# 2   {'ad_name': 'DIN 9021 Шайба плоская увеличенна...
# 3   {'ad_name': 'ГОСТ 6958-78 – шайба плоская увел...
# 4   {'ad_name': 'Шайба плоская, ГОСТ 11371-80', 'u...
# 5   {'ad_name': 'Шайба увеличенная - ЕКТ МШ9021 (D...
# 6   {'ad_name': 'Шайба М 30 цинк ГОСТ 6958 (кг)', ...
# 7   {'ad_name': 'Шайба М 27 ГОСТ 6958 (кг)', 'url'...
# 8   {'ad_name': 'Шайба плоская ГОСТ 11371-70', 'ur...
# 9   {'ad_name': 'Шайба плоская ГОСТ 11371-78, DIN ...
# 10  {'ad_name': 'DIN 125 Шайба плоская ISO 7089, Г...
# 11  {'ad_name': 'Шайба плоская Гост 52646-2006 выс...
# 12  {'ad_name': 'шайба плоская ГОСТ 11371-78', 'ur...
# 13  {'ad_name': 'ГОСТ 11371-78 – шайба плоская нор...
# 14  {'ad_name': 'Шайба плоская усиленная', 'url': ...
# 15  {'ad_name': 'Шайба плоская', 'url': 'https://w...
# 16  {'ad_name': 'Шайба плоская усиленная M12 HDZ I...
# 17  {'ad_name': 'Шайба плоская M6', 'url': 'https:...
# 18  {'ad_name': 'Шайба плоская усиленная M10', 'ur...
# 19  {'ad_name': 'Шайба плоская M6 HDZ IEK', 'url':...
# 20  {'ad_name': 'Шайба плоская усиленная M12', 'ur...
# 21  {'ad_name': 'Шайба плоская M8', 'url': 'https:...
# 22  {'ad_name': 'Шайба плоская усиленная M8 HDZ IE...
# 23  {'ad_name': 'DIN 9021 Шайба плоская увеличенна...
# 24  {'ad_name': 'Шайба плоская увеличенная DIN 902...
# 25  {'ad_name': 'ГОСТ 6958-78 – шайба плоская увел...
# 26  {'ad_name': 'Шайбы плоские по ГОСТ 11371, DIN ...
# 27  {'ad_name': 'Шайба М 27 ГОСТ 6958 (кг)', 'url'...
# 28  {'ad_name': 'Шайбы плоские ГОСТ 6402-70', 'url...
# 29  {'ad_name': 'Шайба плоская ГОСТ 11371-70', 'ur...
# 30  {'ad_name': 'шайба плоская ГОСТ 11371-78', 'ur...
# 31  {'ad_name': 'Шайба плоская, ГОСТ 11371-80', 'u...
# 32  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 33  {'ad_name': 'Шайба М 30 цинк ГОСТ 6958 (кг)', ...
# 34  {'ad_name': 'Шайба плоская ГОСТ 11371-78 (DIN ...
# 35  {'ad_name': 'DIN 125 Шайба плоская ISO 7089, Г...
# 36  {'ad_name': 'Шайба плоская ГОСТ 11371-78, DIN ...
# 37  {'ad_name': 'Шайба увеличенная - ЕКТ МШ9021 (D...
# 38  {'ad_name': 'Шайба плоская М24 ГОСТ 22355-77',...
# 39  {'ad_name': 'Шайба плоская Гост 52646-2006 выс...
# 40  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
# 41  {'ad_name': 'ГОСТ 11371-78 – шайба плоская нор...
# 42  {'ad_name': 'Шайба плоская  ГОСТ 11371', 'url'...
# 43  {'ad_name': 'Шайбы плоские ГОСТ 11371-78', 'ur...
#
#                                             ГОСТ 7798
# 0                                                 NaN
# 1                                                 NaN
# 2   {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 3   {'ad_name': 'Оцинкованный болт с шестигранной ...
# 4   {'ad_name': 'Болт с шестигранной головкой зубр...
# 5   {'ad_name': 'Болт с шестигранной головкой зубр...
# 6   {'ad_name': 'Болт 10*35 ГОСТ 7798-70', 'url': ...
# 7   {'ad_name': 'Болт М 8х100 цинк ГОСТ 7798 (кг)'...
# 8   {'ad_name': 'Болт М 12х35 ГОСТ 7798 кл. пр. 8....
# 9   {'ad_name': 'Болт ГОСТ 7798-70', 'url': 'https...
# 10  {'ad_name': 'Болт М 12х35 ГОСТ 7798 (кг)', 'ur...
# 11  {'ad_name': 'Болт с шестигранной головкой, кла...
# 12  {'ad_name': 'DIN 931 Болт с шестигранной голов...
# 13  {'ad_name': 'Болт медный, болты, болты с шести...
# 14  {'ad_name': 'Болт с шестигранной головкой ГОСТ...
# 15  {'ad_name': 'Болт высокопрочный   М20х110 ГОСТ...
# 16  {'ad_name': 'Болт класс прочности 8.8. ГОСТ 77...
# 17  {'ad_name': 'Болт класс прочности 5.8 ГОСТ 779...
# 18  {'ad_name': 'БОЛТ Свободный ГОСТ 7798-70 (DIN ...
# 19  {'ad_name': 'Болт М20*60 ГОСТ 7798-70', 'url':...
# 20  {'ad_name': 'Болт 42х150 гост - 7798 высокопро...
# 21  {'ad_name': 'Болт с шестигранной головкой, ГОС...
# 22  {'ad_name': 'Болт высокопрочный ГОСТ 7798-70',...
# 23  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 24  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 25  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 26  {'ad_name': '"Болт ГОСТ 7798-70, 7805-70 (в т....
# 27  {'ad_name': 'Болт с шестигранной головкой DIN ...
# 28  {'ad_name': 'Болты с шестигранной головкой ГОС...
# 29  {'ad_name': 'Болт с шестигранной головкой, кла...
# 30  {'ad_name': 'Болты с шестигранной головкой (ГО...
# 31  {'ad_name': 'Болты с шестигранной головкой по ...
# 32  {'ad_name': 'Болты с шестигранной головкой ГОС...
# 33  {'ad_name': 'DIN 931 Болт с шестигранной голов...
# 34  {'ad_name': 'Болт медный, болты, болты с шести...
# 35  {'ad_name': 'Болты с шестигранной головкой ГОС...
# 36  {'ad_name': 'Болты с шестигранной головкой ГОС...
# 37  {'ad_name': 'Болт с шестигранной головкой, ГОС...
# 38  {'ad_name': 'Болт с шестигранной головкой ГОСТ...
# 39  {'ad_name': 'Болты с шестигранной головкой ГОС...
# 40  {'ad_name': 'Болты с шестигранной головкой ГОС...
# 41  {'ad_name': 'Болт Гост 52644-06 класс прочност...
# 42  {'ad_name': 'Болты по ГОСТ 7798 машиностроител...
# 43  {'ad_name': 'Болт ГОСТ 7798-70 м6, м8, м10, м1...

# %%
def identify(data, GOST):
    """
    =====================================================================
    
    Collect names of firms and theirs head office city
    
    Parameters
    ----------
    data : pd.DataFrame, parsed data from parse() function input
    GOST : str, particular GOST of product we want to get
    
    =====================================================================
    """
    
    companies = []
    cities = []
    for i in range(len(data[GOST])):
        
        companies.append(data[GOST][i]['firm'])
        city = data[GOST][i]['location'].split(',')[0]
        cities.append(city if '7' not in city else '' )
        
    return companies, cities

# %%
def CompanyGetInfo(querys, cities, method_search='city'):
    
    """
    =====================================================================
    
    Get general information about company bussiness and match it
    
    Parameters
    ----------
    querys : list, companies to match
    cities : str, city to match company
    method_search : str, method to check company
    
    =====================================================================
    """
    
    s = rq.Session()
    n = 0
    
    p = 0

    for item in querys:
        
        city = cities[p]
        p += 1
        
        query = querys[n]
        r = s.get("https://egrul.nalog.ru/index.html",
            headers={
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0",
                "Accept-Language": "ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3",
                }
            )

        req = rq.Request(
            'POST',
            'https://egrul.nalog.ru/',
            data=b'vyp3CaptchaToken=&page=&query='+query.encode()+b'&region=&PreventChromeAutocomplete=', 
            headers = {
            "Host": "egrul.nalog.ru",
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0",
            "Accept": "application/json, text/javascript, */*; q=0.01",
            "Accept-Language": "ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3",
            "Accept-Encoding": "gzip, deflate, br",
            "Referer": "https://egrul.nalog.ru/index.html",
            "Content-Type": "application/x-www-form-urlencoded",
            "X-Requested-With": "XMLHttpRequest"
            }
            )

        r = s.prepare_request(req)
        r = s.send(r)
    #     print('31',r.text)
        item = json.loads(r.text)
        try:
            if item["ERRORS"] != '' and (item["ERRORS"])["captchaSearch"] != '':
                while True:
                    r = s.get('https://egrul.nalog.ru/captcha-dialog.html',
                    headers = {
                        "Host": "egrul.nalog.ru",
                        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0",
                        "Accept-Language": "ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3",
                        "Referer": "https://egrul.nalog.ru/index.html",
                        "Pragma": "no-cache",
                        "Cache-Control": "no-cache"
                    })
                    b = BeautifulSoup(r.content.decode(),features="lxml").find('div',class_='field-data').find('img').get('src')
                    #print('\r\n\r\nb =',b,'\r\n\r\n')
                    webbrowser.open('https://egrul.nalog.ru' + b)
                    ct = b.split('?a=')[1].split('&')[0]
                    captcha = input('Введите капчу: ')
                    #print('ct=',ct)

                    r = rq.Request(
                    'POST',
                    'https://egrul.nalog.ru/captcha-proc.json',
                    data=b'captcha='+captcha.encode()+b'&captchaToken='+ct.encode(), 
                    headers = {
                        "Host": "egrul.nalog.ru",
                        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0",
                        "Accept": "application/json, text/javascript, */*; q=0.01",
                        "Accept-Language": "ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3",
                        "Accept-Encoding": "gzip, deflate",
                        "Referer": "https://egrul.nalog.ru/index.html"
                        }
                    )

                    r = s.prepare_request(req)
                    r = s.send(r)
                    #print('captcha r', r.text)
                    item = json.loads(r.text)

                    try:
                        tr = False
                        if item["ERRORS"] != '':
                            tr = True
                    except Exception as e:
                        print(e)
                        pass
                    if tr == False: break


        except Exception as e:
            #print(e)
            pass
        t = json.loads(r.text)['t']

        sleep(0.5)

        r = s.get("https://egrul.nalog.ru/search-result/"+str(t),
            headers={
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0",
                "Accept-Language": "ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3",
                "Referer": "https://egrul.nalog.ru/index.html"
                }
            )

        print('95', r.text)
        jsn = json.loads(r.text)

        try:
            if method_search == "city":
                i = 0
                while i < len(jsn["rows"]):

                    address_check = jsn["rows"][i]["a"].replace(",", " ").replace(".", " ").lower().split()
                    city_check = city.lower()
                    if city_check in address_check:
                        jsn["rows"][0] = jsn["rows"][i]
                    i += 1
                if len(jsn["rows"]) > 1:
                    jsn["rows"] = [jsn["rows"][0]]
                if len(jsn["rows"]) == 0:
                    continue
                jsn["rows"][0]["pg"] = '1'
                jsn["rows"][0]["tot"] = '8487671'
        except:
            pass


        try:
            while True:
                if jsn['status'] != 'wait': break
                sleep(0.2)
        except Exception:
            pass

        try:
            item = (jsn["rows"])[0]
            itemParse = ''

            itemParse += item['n'] + '\n'
            itemParse += item['g'] + '\n'
            itemParse += 'Адрес: ' + item['a']+'\n'
            itemParse += 'ИНН: ' + item['i']+'\n'
            itemParse += 'ОГРН: ' + item['o']+'\n'
            itemParse += 'КПП: ' + item['p']+'\n'
            itemParse += 'Дата регистрации: ' + item['r']+'\n'

            try:
                itemParse += 'ДАТА ПРЕКРАЩЕНИЯ ДЕЯТЕЛЬНОСТИ: ' + item['e']+'\n'
            except Exception:
                pass

            if str(item['tot']) != '0':
                if len(item['n']) < 50: name = str(item['n'])
                else: name = str(item['i'])

                name = name.replace('"',"'").replace('\\','⧵').replace('/','⁄').replace('|','¦').replace(':',';').replace('*','✱').replace('?','').replace('<','«').replace('>','»')

                try:
                    os.mkdir(name)
                except Exception:
                    pass
                    name = name + ' '+str(datetime.datetime.strftime(datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=3))),'%x %X %Z')).replace('/','.').replace(':','-')
                    os.mkdir(name)

                f = open(name+'\\'+name+'.txt','w+',encoding='utf-8')
                f.write('по состоянию на ' + str(datetime.datetime.strftime(datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=3))),'%x %X %Z')).replace('/','.')+'\n'+str(itemParse))
                f.close()

                t = item['t']
                
                headers={
                    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0",
                    "Accept-Language": "ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3",
                    "Referer": "https://egrul.nalog.ru/index.html"
                    }
                
                r = s.get("https://egrul.nalog.ru/vyp-request/"+str(t), headers=headers)
                sleep(0.5)
                while True:
                    r = s.get("https://egrul.nalog.ru/vyp-status/"+str(t), headers=headers)
                    st = json.loads(r.text)['status']
                    if st == 'ready': break
                    sleep(0.5)

                r = s.get("https://egrul.nalog.ru/vyp-download/"+str(t), headers=headers)

    #             print(r.text)

                f = open(name+'\\'+name+' выписка.pdf','wb+')
                f.write(r.content)
                f.close()
                n += 1
                sleep(5)

        except Exception as e:
            #print(e)
            traceback.print_exc()
            pass
        
        return jsn

# %%
def range(company_info):
    company_info = pd.DataFrame(company_info)
    company_info["Уставной капитал"] = company_info["Уставной капитал"].astype("float64")

    ust_cof = 5/company_info["Уставной капитал"].max()
    company_info["баллы"] = 0
    for el_number in range(len(company_info["баллы"])):
        company_info["баллы"][el_number] += company_info["Уставной капитал"][el_number] * ust_cof
    company_info.to_excel(company_info.xls)
    
    return company_info

# %%
headers = {"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
           "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36",  
          }

# %%
data = proceed_data('poiskpostav_v1.xlsx')

# %%
searcher = searchQuery(data,mode='gost')

# %%
dct = parse(data, headers=headers, mode='reasonable', source='all')

# %%
querys, cities = identify(dct, 'ГОСТ 22704')

# %%
queries = [[x] for x in querys]

# %%
jsn = CompanyGetInfo(queries[0], cities[0], method_search='city')

# %%
import PyPDF2
pdfFiles = []

for filename in os.listdir('.'):
    if filename.endswith('.pdf'):
        pdfFiles.append(filename)
pdfFiles.sort()

pdfWriter = PyPDF2.PdfFileWriter()

for filename in pdfFiles:
    pdfFileObj = open(filename, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

    for pageNum in range(0, 6):
        pageObj = pdfReader.getPage(pageNum)
        pdfWriter.addPage(pageObj)

pdfOutput = open('all-small.pdf', 'wb')
pdfWriter.write(pdfOutput)
pdfOutput.close()

# %%
import fitz 
import os

filename = "all-small.pdf"  
search_term = 'П'  
pdf_document = fitz.open(filename)

for current_page in range(len(pdf_document)):  
    page = pdf_document.loadPage(current_page)
    if page.searchFor(search_term):
        print("%s найдено на странице %i" % (search_term, current_page+1))

# %%
text = {}
with fitz.open('all-small.pdf') as doc:
    for num, page in enumerate(doc.pages()):
        text[num] = page.get_text()

# %%
import re
ter = str(text)

pattern_company = 'nСокращенное наименование на русскомnязыкеnООО (.*?)n'
pattern_ustcapital = "nРазмер в рубляхn(.*?)n" 
pattern_mesto = 'nМесто нахождения юридического лицаn(.*?)n'
pattern_data = 'nДата регистрацииn(.*?)n'

company_info = []

ter = ter.replace('\\','')
ter = ter.replace(')','')
ter = ter.replace('(','')

for i in re.findall("(?s)ВЫПИСКА(.*?)Сведения о записях, внесенных в Единый государственный реестр юридических лиц", ter):
    company_info.append({ "Компания": ''.join(re.findall(pattern_company, i)), "Уставной капитал": ''.join(re.findall(pattern_ustcapital, i)), 
                        "Место нахождения юридического лица": ''.join(re.findall(pattern_mesto, i)), "Дата регистрации": ''.join(re.findall(pattern_data, i)) 
                        })
print(company_info)
    
    

re.findall(pattern, ter)

# %%
pattern_data = 'nДата регистрацииn(.*?)n'
for i in re.findall("(?s)ВЫПИСКА(.*?)Сведения о записях, внесенных в Единый государственный реестр юридических лиц", ter):
    company_info.append({"Дата регестрации": re.findall(pattern_data, i)})
print(company_info)

# %%
for i in re.findall("(?s)ВЫПИСКА(.*?)Сведения о записях, внесенных в Единый государственный реестр юридических лиц", ter):
    company_info.append({"Место нахождения": re.findall(pattern_mesto, i)})
print(company_info)

# %%
info = range(jsn)

# %%
company_info["баллы"] = 0
company_info
